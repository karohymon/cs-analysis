# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import mceq_config as config
from MCEq.core import MCEqRun
import crflux.models as pm
import scienceplots
import scipy.optimize as opt
from utils.helpers import *
from csmodification_analyzer import SensitivityAnalyzer

# %%
doy = doys(5)

# %%
analyzer = SensitivityAnalyzer(ptype='numu', scale_factor_p=1., scale_factor_k=0.8, doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')

# %%
# Load data
analyzer.load_data()

# Calculate amplitudes
#analyzer.get_amplitudes()

# Plot deviations
analyzer.deviation_sv_amplitude_plot()

#analyzer.sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
analyzer = SensitivityAnalyzer(ptype='numu', scale_factor_p=0.5, scale_factor_k=0.5, doys=doy, threshold=1.e4, increase='const',interactionmodel= 'EPOSLHC')

analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
#example

analyzer = SensitivityAnalyzer(ptype='numu', scale_factor_p=2., scale_factor_k=1., doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')

analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
analyzer = SensitivityAnalyzer(ptype='mu', scale_factor_p=1.5, scale_factor_k=1., doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')
analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
analyzer = SensitivityAnalyzer(ptype='mu', scale_factor_p=0.5, scale_factor_k=1., doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')
analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
analyzer = SensitivityAnalyzer(ptype='mu', scale_factor_p=1.2, scale_factor_k=1., doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')
analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
analyzer = SensitivityAnalyzer(ptype='mu', scale_factor_p=0.8, scale_factor_k=1., doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')
analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
analyzer = SensitivityAnalyzer(ptype='mu', scale_factor_p=2., scale_factor_k=1., doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')
analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
analyzer = SensitivityAnalyzer(ptype='numu', scale_factor_p=0.5, scale_factor_k=0.5, doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')
analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
analyzer = SensitivityAnalyzer(ptype='numu', scale_factor_p=0.5, scale_factor_k=1., doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')
analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
analyzer = SensitivityAnalyzer(ptype='numu', scale_factor_p=0.8, scale_factor_k=1., doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')
analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
analyzer = SensitivityAnalyzer(ptype='numu', scale_factor_p=0.5, scale_factor_k=1.5, doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')
analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
analyzer = SensitivityAnalyzer(ptype='numu', scale_factor_p=1., scale_factor_k=0.5, doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')
analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
analyzer = SensitivityAnalyzer(ptype='numu', scale_factor_p=1., scale_factor_k=0.8, doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')
analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
analyzer = SensitivityAnalyzer(ptype='numu', scale_factor_p=1., scale_factor_k=1.2, doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')
analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
analyzer = SensitivityAnalyzer(ptype='numu', scale_factor_p=1., scale_factor_k=1.5, doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')
analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
analyzer = SensitivityAnalyzer(ptype='numu', scale_factor_p=1.2, scale_factor_k=0.8, doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')
analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
analyzer = SensitivityAnalyzer(ptype='numu', scale_factor_p=1.5, scale_factor_k=0.5, doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')
analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
analyzer = SensitivityAnalyzer(ptype='numu', scale_factor_p=1.5, scale_factor_k=0.8, doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')
analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
analyzer = SensitivityAnalyzer(ptype='numu', scale_factor_p=1.5, scale_factor_k=1., doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')
analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
analyzer = SensitivityAnalyzer(ptype='numu', scale_factor_p=1.5, scale_factor_k=1.5, doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')
analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
analyzer = SensitivityAnalyzer(ptype='numu', scale_factor_p=2., scale_factor_k=0.8, doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')
analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
analyzer = SensitivityAnalyzer(ptype='numu', scale_factor_p=2., scale_factor_k=1., doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')
analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a

# %%
analyzer = SensitivityAnalyzer(ptype='mu', scale_factor_p=1., scale_factor_k=0.6, doys=doy, threshold=1.e4, increase='const',interactionmodel='SIBYLL2.3c')
analyzer.load_data()
analyzer.deviation_sv_amplitude_plot()
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a
