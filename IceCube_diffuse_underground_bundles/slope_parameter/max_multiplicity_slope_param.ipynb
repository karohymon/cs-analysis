# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import Normalize
import pickle
import numpy as np
import crflux.models as pm
import  mceq_underground_helpers_oneregion_threshold as helper
import slope_param_functions as sp

# %%
plot_dir = '/hetghome/khymon/Plots/cs-analysis/'

# %%
cs_p_values = [1.00,1.01] #[0.5,0.6,0.7,0.8,0.9,1.0,1.1,1.2,1.3,1.4,1.5]  # List of cross-section values: pion-air
cs_k_values = [1.00]
cs_pr_values = [1.00]
ptype_values = [2212] 
season_values = ["jan", "apr", "jul"]  #  seasons
e0_values = [2.05,2.15,2.25,2.35,2.45,2.55,2.65,2.75,2.85,2.95,3.05,3.15,3.25,3.35,3.45,3.55,3.65,3.75,3.85,3.95,4.05,4.15,4.25,4.35,4.45,4.55,4.65,4.75,4.85]
e1_values = [2.25,2.35,2.45,2.55,2.65,2.75,2.85,2.95,3.05,3.15,3.25,3.35,3.45,3.55,3.65,3.75,3.85,3.95,4.05,4.15,4.25,4.35,4.45,4.55,4.65,4.75,4.85,4.95,5.05]
e_center = e0_values + np.ones(len(e0_values))*0.1
pairwise = True


helper.initialize_flux_dicts(
        ptype_values, cs_p_values, cs_k_values, cs_pr_values, e0_values, e1_values if 'e1_values' in locals() else [None], pairwise=pairwise
)
# Out:
# 2.05 2.25
# helper script 2.05 2.25 1.01 1.0 1.0
# 2.15 2.35
# helper script 2.15 2.35 1.01 1.0 1.0
# 2.25 2.45
# helper script 2.25 2.45 1.01 1.0 1.0
# 2.35 2.55
# helper script 2.35 2.55 1.01 1.0 1.0
# 2.45 2.65
# helper script 2.45 2.65 1.01 1.0 1.0
# 2.55 2.75
# helper script 2.55 2.75 1.01 1.0 1.0
# 2.65 2.85
# helper script 2.65 2.85 1.01 1.0 1.0
# 2.75 2.95
# helper script 2.75 2.95 1.01 1.0 1.0
# 2.85 3.05
# helper script 2.85 3.05 1.01 1.0 1.0
# 2.95 3.15
# helper script 2.95 3.15 1.01 1.0 1.0
# 3.05 3.25
# helper script 3.05 3.25 1.01 1.0 1.0
# 3.15 3.35
# helper script 3.15 3.35 1.01 1.0 1.0
# 3.25 3.45
# helper script 3.25 3.45 1.01 1.0 1.0
# 3.35 3.55
# helper script 3.35 3.55 1.01 1.0 1.0
# 3.45 3.65
# helper script 3.45 3.65 1.01 1.0 1.0
# 3.55 3.75
# helper script 3.55 3.75 1.01 1.0 1.0
# 3.65 3.85
# helper script 3.65 3.85 1.01 1.0 1.0
# 3.75 3.95
# helper script 3.75 3.95 1.01 1.0 1.0
# 3.85 4.05
# helper script 3.85 4.05 1.01 1.0 1.0
# 3.95 4.15
# helper script 3.95 4.15 1.01 1.0 1.0
# 4.05 4.25
# helper script 4.05 4.25 1.01 1.0 1.0
# 4.15 4.35
# helper script 4.15 4.35 1.01 1.0 1.0
# 4.25 4.45
# helper script 4.25 4.45 1.01 1.0 1.0
# 4.35 4.55
# helper script 4.35 4.55 1.01 1.0 1.0
# 4.45 4.65
# helper script 4.45 4.65 1.01 1.0 1.0
# 4.55 4.75
# helper script 4.55 4.75 1.01 1.0 1.0
# 4.65 4.85
# helper script 4.65 4.85 1.01 1.0 1.0
# 4.75 4.95
# helper script 4.75 4.95 1.01 1.0 1.0
# 4.85 5.05
# helper script 4.85 5.05 1.01 1.0 1.0
# Key: (2212, 1.0, 1.0, 1.0, 2.05, 'inf')
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 2.05, 2.25)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 2.15, 2.35)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 2.25, 2.45)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 2.35, 2.55)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 2.45, 2.65)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 2.55, 2.75)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 2.65, 2.85)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 2.75, 2.95)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 2.85, 3.05)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 2.95, 3.15)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 3.05, 3.25)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 3.15, 3.35)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 3.25, 3.45)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 3.35, 3.55)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 3.45, 3.65)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 3.55, 3.75)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 3.65, 3.85)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 3.75, 3.95)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 3.85, 4.05)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 3.95, 4.15)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 4.05, 4.25)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 4.15, 4.35)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 4.25, 4.45)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 4.35, 4.55)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 4.45, 4.65)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 4.55, 4.75)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 4.65, 4.85)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 4.75, 4.95)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.01, 1.0, 1.0, 4.85, 5.05)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)

# %%
cs_p = 1.0
cs_k = 1.01
cs_pr = 1.0
angle = 0.0
season = "apr"
threshold=500.
d =1.5
e0 = 3.25
e1 = 3.45

# %%
x_log = np.log10(helper.n_mu_vec)


helper.some_function_that_uses_angles()
angles = helper.angles

sl = sp.sl_depth(1.5,angles)

sp.get_log_y(sl, angle,cs_p,cs_k,e0,e1,season,threshold)

# %%
def get_derivative(x_log, log_y,m_max):

    deriv_low = (log_y[19] - log_y[1])/(np.log10(x_log[19])-np.log10(x_log[1])) 
    deriv_high = (log_y[m_max] - log_y[59])/(np.log10(x_log[m_max])-np.log10(x_log[59])) 

    return np.array([deriv_low, deriv_high])
