# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import Normalize
import matplotlib.lines as mlines
from scipy.interpolate import UnivariateSpline
from tqdm import tqdm
import pickle
import numpy as np

import crflux.models as pm
import mceq_underground_helpers_cs as mh
from MCEq.data import InteractionCrossSections
from MCEq.core import MCEqRun
import  mceq_underground_helpers_oneregion as helper

# %%
cs_k_values = [1.00] #[0.5,0.6,0.7,0.8,0.9,1.0,1.1,1.2,1.3,1.4,1.5]  # List of cross-section values: pion-air
cs_p_values = [1.00]
cs_pr_values = [1.00,1.01]
ptype_values = [2212] 
season_values = ["jan", "apr", "jul"]  #  seasons
e0_values = [2.05,2.15,2.25,2.35,2.45,2.55,2.65,2.75,2.85,2.95,3.05,3.15,3.25,3.35,3.45,3.55,3.65,3.75,3.85,3.95,4.05,4.15,4.25,4.35,4.45,4.55,4.65,4.75,4.85]
e1_values = [2.25,2.35,2.45,2.55,2.65,2.75,2.85,2.95,3.05,3.15,3.25,3.35,3.45,3.55,3.65,3.75,3.85,3.95,4.05,4.15,4.25,4.35,4.45,4.55,4.65,4.75,4.85,4.95,5.05]
pairwise = True


helper.initialize_flux_dicts(
        ptype_values, cs_p_values, cs_k_values, cs_pr_values, e0_values, e1_values if 'e1_values' in locals() else [None], pairwise=pairwise
) 

helper.some_function_that_uses_angles()
angles = helper.angles
X = helper.slant_depths[2:-1:4]
# Out:
# helper script 2.05 2.25 1.0 1.0 1.01
# helper script 2.15 2.35 1.0 1.0 1.01
# helper script 2.25 2.45 1.0 1.0 1.01
# helper script 2.35 2.55 1.0 1.0 1.01
# helper script 2.45 2.65 1.0 1.0 1.01
# helper script 2.55 2.75 1.0 1.0 1.01
# helper script 2.65 2.85 1.0 1.0 1.01
# helper script 2.75 2.95 1.0 1.0 1.01
# helper script 2.85 3.05 1.0 1.0 1.01
# helper script 2.95 3.15 1.0 1.0 1.01
# helper script 3.05 3.25 1.0 1.0 1.01
# helper script 3.15 3.35 1.0 1.0 1.01
# helper script 3.25 3.45 1.0 1.0 1.01
# helper script 3.35 3.55 1.0 1.0 1.01
# helper script 3.45 3.65 1.0 1.0 1.01
# helper script 3.55 3.75 1.0 1.0 1.01
# helper script 3.65 3.85 1.0 1.0 1.01
# helper script 3.75 3.95 1.0 1.0 1.01
# helper script 3.85 4.05 1.0 1.0 1.01
# helper script 3.95 4.15 1.0 1.0 1.01
# helper script 4.05 4.25 1.0 1.0 1.01
# helper script 4.15 4.35 1.0 1.0 1.01
# helper script 4.25 4.45 1.0 1.0 1.01
# helper script 4.35 4.55 1.0 1.0 1.01
# helper script 4.45 4.65 1.0 1.0 1.01
# helper script 4.55 4.75 1.0 1.0 1.01
# helper script 4.65 4.85 1.0 1.0 1.01
# helper script 4.75 4.95 1.0 1.0 1.01
# helper script 4.85 5.05 1.0 1.0 1.01
# Key: (2212, 1.0, 1.0, 1.0, 2.05, 'inf')
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 2.05, 2.25)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 2.15, 2.35)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 2.25, 2.45)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 2.35, 2.55)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 2.45, 2.65)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 2.55, 2.75)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 2.65, 2.85)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 2.75, 2.95)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 2.85, 3.05)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 2.95, 3.15)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 3.05, 3.25)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 3.15, 3.35)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 3.25, 3.45)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 3.35, 3.55)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 3.45, 3.65)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 3.55, 3.75)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 3.65, 3.85)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 3.75, 3.95)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 3.85, 4.05)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 3.95, 4.15)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 4.05, 4.25)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 4.15, 4.35)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 4.25, 4.45)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 4.35, 4.55)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 4.45, 4.65)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 4.55, 4.75)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 4.65, 4.85)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 4.75, 4.95)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)
# Key: (2212, 1.0, 1.0, 1.01, 4.85, 5.05)
# Length of cos_thetas: 6
# Shape of flux for season jan: (6, 121)
# Shape of flux for season apr: (6, 121)
# Shape of flux for season jul: (6, 121)

# %%
plot_dir = '/hetghome/khymon/Plots/cs-analysis/'

# %%
# get pion cross section
mceq_instance = MCEqRun(
        interaction_model="SIBYLL23C",
        theta_deg=0.0,
        primary_model=(pm.GlobalSplineFitBeta, None),
        density_model = ('MSIS00_IC',('South Pole','January')),
    )


cs_proton = InteractionCrossSections(mceq_instance._mceq_db, interaction_model="SIBYLL23C").get_cs(2212, mbarn=True)
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to MSIS00_IC ('South Pole', 'January')
# MSIS00IceCubeCentered::set_theta(): latitude = -90.00 for zenith angle =  0.00
# MCEqRun::set_primary_model(): GlobalSplineFitBeta

# %%
# Load the pickle file - see file with fixed norm 4.05 in same folder, here norm is changed according to current e0
#default order: (str(d), str(cs_p1), str(cs_p2), str(cs_k2), str(ptype), season, str(e0))

# normalization flag
norm = False

if norm:

    with open("/hetghome/khymon/cs-files/R_value_const_pi-air_k-air_pr-air_sibyll23c_smooth_oneregion_energybin_test_proton.pkl", "rb") as file:
        data = pickle.load(file)

else:
    with open("/hetghome/khymon/cs-files/R_value_const_pi-air_k-air_pr-air_sibyll23c_smooth_oneregion_energybin_test_proton_nonorm.pkl", "rb") as file:
        data = pickle.load(file)

# Print or inspect the data
print(data)
# Out:
# {('1.5', '1.0', '1.0', '1.0', '2212', 'jan', '2.05', 'inf'): (array([4.48226310e-05, 4.85627721e-05, 5.28496790e-05, 5.83037731e-05,
#        6.49225780e-05, 7.28977514e-05]), array([0.00020249, 0.00054492, 0.0011649 , 0.00211498, 0.0035152 ,
#        0.0053082 ]), array([9.07630954e-09, 2.64629279e-08, 6.15645226e-08, 1.23311149e-07,
#        2.28215998e-07, 3.86955849e-07])), ('1.5', '1.0', '1.0', '1.0', '2212', 'apr', '2.05', 'inf'): (array([4.84124814e-05, 5.24411267e-05, 5.70397214e-05, 6.25745447e-05,
#        6.96276325e-05, 7.79682006e-05]), array([0.00018474, 0.00049567, 0.00105766, 0.00192373, 0.00318812,
#        0.00481121]), array([8.94351900e-09, 2.59932393e-08, 6.03286567e-08, 1.20376599e-07,
#        2.21981009e-07, 3.75121348e-07])), ('1.5', '1.0', '1.0', '1.0', '2212', 'jul', '2.05', 'inf'): (array([5.23442020e-05, 5.63753157e-05, 6.12945583e-05, 6.65843833e-05,
#        7.35814095e-05, 8.18216528e-05]), array([0.00015038, 0.00040504, 0.00086406, 0.00157993, 0.00262103,
#        0.00396132]), array([7.87135515e-09, 2.28344712e-08, 5.29624669e-08, 1.05198763e-07,
#        1.92859035e-07, 3.24121439e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '2.05', '2.25'): (array([4.48226310e-05, 4.85627721e-05, 5.28496790e-05, 5.83037731e-05,
#        6.49225780e-05, 7.28977514e-05]), array([0.00020249, 0.00054492, 0.0011649 , 0.00211498, 0.0035152 ,
#        0.0053082 ]), array([9.07630954e-09, 2.64629279e-08, 6.15645226e-08, 1.23311149e-07,
#        2.28215998e-07, 3.86955849e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '2.15', '2.35'): (array([4.48226310e-05, 4.85627721e-05, 5.28496790e-05, 5.83037731e-05,
#        6.49225780e-05, 7.28977514e-05]), array([0.00020249, 0.00054492, 0.0011649 , 0.00211498, 0.0035152 ,
#        0.0053082 ]), array([9.07630954e-09, 2.64629279e-08, 6.15645226e-08, 1.23311149e-07,
#        2.28215998e-07, 3.86955849e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '2.25', '2.45'): (array([4.48226310e-05, 4.85627721e-05, 5.28496790e-05, 5.83037731e-05,
#        6.49225780e-05, 7.28977514e-05]), array([0.00020249, 0.00054492, 0.0011649 , 0.00211498, 0.0035152 ,
#        0.0053082 ]), array([9.07630954e-09, 2.64629279e-08, 6.15645226e-08, 1.23311149e-07,
#        2.28215998e-07, 3.86955849e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '2.35', '2.55'): (array([4.48226310e-05, 4.85627721e-05, 5.28496790e-05, 5.83037731e-05,
#        6.49225780e-05, 7.28977514e-05]), array([0.00020249, 0.00054492, 0.0011649 , 0.00211498, 0.0035152 ,
#        0.0053082 ]), array([9.07630954e-09, 2.64629279e-08, 6.15645226e-08, 1.23311149e-07,
#        2.28215997e-07, 3.86955846e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '2.45', '2.65'): (array([4.48226310e-05, 4.85627721e-05, 5.28496790e-05, 5.83037731e-05,
#        6.49225780e-05, 7.28977514e-05]), array([0.00020249, 0.00054492, 0.0011649 , 0.00211498, 0.0035152 ,
#        0.0053082 ]), array([9.07630954e-09, 2.64629279e-08, 6.15645226e-08, 1.23311148e-07,
#        2.28215992e-07, 3.86955831e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '2.55', '2.75'): (array([4.48226310e-05, 4.85627721e-05, 5.28496790e-05, 5.83037731e-05,
#        6.49225781e-05, 7.28977516e-05]), array([0.00020249, 0.00054492, 0.0011649 , 0.00211498, 0.0035152 ,
#        0.00530819]), array([9.07630954e-09, 2.64629279e-08, 6.15645219e-08, 1.23311121e-07,
#        2.28215844e-07, 3.86955414e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '2.65', '2.85'): (array([4.48226310e-05, 4.85627721e-05, 5.28496790e-05, 5.83037733e-05,
#        6.49225787e-05, 7.28977529e-05]), array([0.00020249, 0.00054492, 0.0011649 , 0.00211497, 0.00351518,
#        0.00530815]), array([9.07630954e-09, 2.64629276e-08, 6.15645190e-08, 1.23310897e-07,
#        2.28214639e-07, 3.86952073e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '2.75', '2.95'): (array([4.48226310e-05, 4.85627721e-05, 5.28496791e-05, 5.83037736e-05,
#        6.49225803e-05, 7.28977565e-05]), array([0.00020249, 0.00054492, 0.0011649 , 0.00211495, 0.00351511,
#        0.00530798]), array([9.07630945e-09, 2.64629265e-08, 6.15643996e-08, 1.23309786e-07,
#        2.28209886e-07, 3.86939797e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '2.85', '3.05'): (array([4.48226310e-05, 4.85627722e-05, 5.28496791e-05, 5.83037737e-05,
#        6.49225817e-05, 7.28977602e-05]), array([0.00020249, 0.00054492, 0.00116488, 0.00211489, 0.00351493,
#        0.00530762]), array([9.07630913e-09, 2.64628708e-08, 6.15636269e-08, 1.23306253e-07,
#        2.28198523e-07, 3.86913307e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '2.95', '3.15'): (array([4.48226310e-05, 4.85627722e-05, 5.28496777e-05, 5.83037709e-05,
#        6.49225780e-05, 7.28977557e-05]), array([0.00020249, 0.00054491, 0.00116484, 0.00211476, 0.00351464,
#        0.00530708]), array([9.07629048e-09, 2.64624923e-08, 6.15612162e-08, 1.23298589e-07,
#        2.28179400e-07, 3.86873892e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '3.05', '3.25'): (array([4.48226309e-05, 4.85627708e-05, 5.28496706e-05, 5.83037585e-05,
#        6.49225597e-05, 7.28977316e-05]), array([0.00020249, 0.00054489, 0.00116475, 0.00211456, 0.00351426,
#        0.00530646]), array([9.07616707e-09, 2.64613325e-08, 6.15565194e-08, 1.23286649e-07,
#        2.28154793e-07, 3.86829116e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '3.15', '3.35'): (array([4.48226293e-05, 4.85627640e-05, 5.28496506e-05, 5.83037265e-05,
#        6.49225146e-05, 7.28976700e-05]), array([0.00020248, 0.00054484, 0.00116462, 0.00211431, 0.00351387,
#        0.0053059 ]), array([9.07578558e-09, 2.64591343e-08, 6.15499431e-08, 1.23272435e-07,
#        2.28129303e-07, 3.86787784e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '3.25', '3.45'): (array([4.48226226e-05, 4.85627449e-05, 5.28496079e-05, 5.83036642e-05,
#        6.49224284e-05, 7.28975475e-05]), array([0.00020247, 0.00054478, 0.00116449, 0.00211408, 0.00351354,
#        0.00530547]), array([9.07505253e-09, 2.64561470e-08, 6.15427074e-08, 1.23258726e-07,
#        2.28107309e-07, 3.86755922e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '3.35', '3.55'): (array([4.48226048e-05, 4.85627057e-05, 5.28495347e-05, 5.83035603e-05,
#        6.49222804e-05, 7.28973365e-05]), array([0.00020244, 0.00054472, 0.00116436, 0.0021139 , 0.0035133 ,
#        0.00530522]), array([9.07403959e-09, 2.64529520e-08, 6.15360893e-08, 1.23247641e-07,
#        2.28091566e-07, 3.86736419e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '3.45', '3.65'): (array([4.48225675e-05, 4.85626351e-05, 5.28494183e-05, 5.83033933e-05,
#        6.49220368e-05, 7.28969849e-05]), array([0.00020242, 0.00054466, 0.00116427, 0.00211377, 0.00351319,
#        0.00530516]), array([9.07293018e-09, 2.64500849e-08, 6.15309366e-08, 1.23240245e-07,
#        2.28083169e-07, 3.86729894e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '3.55', '3.75'): (array([4.48224996e-05, 4.85625157e-05, 5.28492329e-05, 5.83031218e-05,
#        6.49216559e-05, 7.28964256e-05]), array([0.0002024 , 0.00054462, 0.00116421, 0.00211373, 0.00351319,
#        0.00530527]), array([9.07191006e-09, 2.64478906e-08, 6.15276906e-08, 1.23236911e-07,
#        2.28082158e-07, 3.86735520e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '3.65', '3.85'): (array([4.48223926e-05, 4.85623414e-05, 5.28489700e-05, 5.83027370e-05,
#        6.49211213e-05, 7.28956224e-05]), array([0.00020238, 0.00054459, 0.0011642 , 0.00211375, 0.00351331,
#        0.00530556]), array([9.07111302e-09, 2.64465694e-08, 6.15265591e-08, 1.23237675e-07,
#        2.28088077e-07, 3.86751810e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '3.75', '3.95'): (array([4.48222422e-05, 4.85621235e-05, 5.28486454e-05, 5.83022569e-05,
#        6.49204108e-05, 7.28945320e-05]), array([0.00020237, 0.00054459, 0.00116422, 0.00211385, 0.00351353,
#        0.00530597]), array([9.07061821e-09, 2.64462073e-08, 6.15275255e-08, 1.23242199e-07,
#        2.28099894e-07, 3.86776478e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '3.85', '4.05'): (array([4.48220550e-05, 4.85618678e-05, 5.28482471e-05, 5.83016350e-05,
#        6.49194507e-05, 7.28930079e-05]), array([0.00020237, 0.0005446 , 0.00116428, 0.002114  , 0.00351383,
#        0.00530649]), array([9.07045700e-09, 2.64467574e-08, 6.15302750e-08, 1.23249620e-07,
#        2.28115830e-07, 3.86806301e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '3.95', '4.15'): (array([4.48218442e-05, 4.85615678e-05, 5.28477401e-05, 5.83007979e-05,
#        6.49181223e-05, 7.28908076e-05]), array([0.00020237, 0.00054463, 0.00116437, 0.00211419, 0.00351418,
#        0.00530709]), array([9.07061628e-09, 2.64480619e-08, 6.15343222e-08, 1.23258886e-07,
#        2.28133995e-07, 3.86838223e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '4.05', '4.25'): (array([4.48216120e-05, 4.85611965e-05, 5.28470791e-05, 5.82996767e-05,
#        6.49162025e-05, 7.28875927e-05]), array([0.00020238, 0.00054467, 0.00116448, 0.0021144 , 0.00351457,
#        0.00530776]), array([9.07104737e-09, 2.64499091e-08, 6.15391645e-08, 1.23269047e-07,
#        2.28152829e-07, 3.86869926e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '4.15', '4.35'): (array([4.48213519e-05, 4.85607214e-05, 5.28461971e-05, 5.82981165e-05,
#        6.49133985e-05, 7.28830048e-05]), array([0.0002024 , 0.00054472, 0.00116459, 0.00211464, 0.00351501,
#        0.0053085 ]), array([9.07167598e-09, 2.64520697e-08, 6.15443274e-08, 1.23279286e-07,
#        2.28171101e-07, 3.86899721e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '4.25', '4.45'): (array([4.48210399e-05, 4.85601160e-05, 5.28450314e-05, 5.82958562e-05,
#        6.49094263e-05, 7.28769976e-05]), array([0.00020241, 0.00054477, 0.00116472, 0.00211488, 0.00351548,
#        0.00530931]), array([9.07241971e-09, 2.64543359e-08, 6.15494287e-08, 1.23289012e-07,
#        2.28188002e-07, 3.86926666e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '4.35', '4.55'): (array([4.48206603e-05, 4.85593301e-05, 5.28434440e-05, 5.82926392e-05,
#        6.49041713e-05, 7.28702045e-05]), array([0.00020243, 0.00054483, 0.00116484, 0.00211515, 0.003516  ,
#        0.00531013]), array([9.07320716e-09, 2.64565524e-08, 6.15542122e-08, 1.23297877e-07,
#        2.28203100e-07, 3.86950348e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '4.45', '4.65'): (array([4.48201989e-05, 4.85582635e-05, 5.28411683e-05, 5.82884298e-05,
#        6.48981610e-05, 7.28641076e-05]), array([0.00020245, 0.00054488, 0.00116497, 0.00211544, 0.00351653,
#        0.00531085]), array([9.07398223e-09, 2.64586151e-08, 6.15585280e-08, 1.23305711e-07,
#        2.28216247e-07, 3.86970703e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '4.55', '4.75'): (array([4.48195900e-05, 4.85567849e-05, 5.28379456e-05, 5.82835936e-05,
#        6.48927384e-05, 7.28609121e-05]), array([0.00020247, 0.00054494, 0.00116512, 0.00211573, 0.003517  ,
#        0.00531132]), array([9.07470478e-09, 2.64604620e-08, 6.15623072e-08, 1.23312465e-07,
#        2.28227471e-07, 3.86987919e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '4.65', '4.85'): (array([4.48187809e-05, 4.85547042e-05, 5.28337438e-05, 5.82789900e-05,
#        6.48898619e-05, 7.28628048e-05]), array([0.00020249, 0.00054499, 0.00116527, 0.002116  , 0.0035173 ,
#        0.00531138]), array([9.07535286e-09, 2.64620695e-08, 6.15655460e-08, 1.23318183e-07,
#        2.28236900e-07, 3.87002310e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '4.75', '4.95'): (array([4.48177046e-05, 4.85518081e-05, 5.28289816e-05, 5.82759712e-05,
#        6.48914521e-05, 7.28674168e-05]), array([0.00020251, 0.00054506, 0.00116543, 0.00211619, 0.00351733,
#        0.00531121]), array([9.07591821e-09, 2.64634400e-08, 6.15682748e-08, 1.23322958e-07,
#        2.28244740e-07, 3.87014267e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jan', '4.85', '5.05'): (array([4.48162370e-05, 4.85480295e-05, 5.28246820e-05, 5.82759870e-05,
#        6.48954235e-05, 7.21895110e-05]), array([0.00020252, 0.00054512, 0.00116556, 0.00211626, 0.00351722,
#        0.00536122]), array([9.07640118e-09, 2.64645915e-08, 6.15705438e-08, 1.23326911e-07,
#        2.28251226e-07, 3.87024152e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '2.05', '2.25'): (array([4.84124814e-05, 5.24411267e-05, 5.70397214e-05, 6.25745447e-05,
#        6.96276325e-05, 7.79682006e-05]), array([0.00018474, 0.00049567, 0.00105766, 0.00192373, 0.00318812,
#        0.00481121]), array([8.94351900e-09, 2.59932393e-08, 6.03286567e-08, 1.20376599e-07,
#        2.21981009e-07, 3.75121348e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '2.15', '2.35'): (array([4.84124814e-05, 5.24411267e-05, 5.70397214e-05, 6.25745447e-05,
#        6.96276325e-05, 7.79682006e-05]), array([0.00018474, 0.00049567, 0.00105766, 0.00192373, 0.00318812,
#        0.00481121]), array([8.94351900e-09, 2.59932393e-08, 6.03286567e-08, 1.20376599e-07,
#        2.21981009e-07, 3.75121348e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '2.25', '2.45'): (array([4.84124814e-05, 5.24411267e-05, 5.70397214e-05, 6.25745447e-05,
#        6.96276325e-05, 7.79682006e-05]), array([0.00018474, 0.00049567, 0.00105766, 0.00192373, 0.00318812,
#        0.00481121]), array([8.94351900e-09, 2.59932393e-08, 6.03286567e-08, 1.20376599e-07,
#        2.21981009e-07, 3.75121348e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '2.35', '2.55'): (array([4.84124814e-05, 5.24411267e-05, 5.70397214e-05, 6.25745447e-05,
#        6.96276325e-05, 7.79682006e-05]), array([0.00018474, 0.00049567, 0.00105766, 0.00192373, 0.00318812,
#        0.00481121]), array([8.94351900e-09, 2.59932393e-08, 6.03286567e-08, 1.20376599e-07,
#        2.21981008e-07, 3.75121345e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '2.45', '2.65'): (array([4.84124814e-05, 5.24411267e-05, 5.70397214e-05, 6.25745447e-05,
#        6.96276325e-05, 7.79682006e-05]), array([0.00018474, 0.00049567, 0.00105766, 0.00192373, 0.00318812,
#        0.00481121]), array([8.94351900e-09, 2.59932393e-08, 6.03286567e-08, 1.20376598e-07,
#        2.21981003e-07, 3.75121332e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '2.55', '2.75'): (array([4.84124814e-05, 5.24411267e-05, 5.70397214e-05, 6.25745447e-05,
#        6.96276326e-05, 7.79682009e-05]), array([0.00018474, 0.00049567, 0.00105766, 0.00192373, 0.00318811,
#        0.0048112 ]), array([8.94351900e-09, 2.59932393e-08, 6.03286560e-08, 1.20376572e-07,
#        2.21980865e-07, 3.75120941e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '2.65', '2.85'): (array([4.84124814e-05, 5.24411267e-05, 5.70397214e-05, 6.25745449e-05,
#        6.96276334e-05, 7.79682026e-05]), array([0.00018474, 0.00049567, 0.00105766, 0.00192373, 0.0031881 ,
#        0.00481116]), array([8.94351900e-09, 2.59932390e-08, 6.03286533e-08, 1.20376362e-07,
#        2.21979736e-07, 3.75117821e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '2.75', '2.95'): (array([4.84124814e-05, 5.24411267e-05, 5.70397215e-05, 6.25745456e-05,
#        6.96276358e-05, 7.79682077e-05]), array([0.00018474, 0.00049567, 0.00105766, 0.00192371, 0.00318803,
#        0.00481102]), array([8.94351892e-09, 2.59932380e-08, 6.03285410e-08, 1.20375320e-07,
#        2.21975294e-07, 3.75106385e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '2.85', '3.05'): (array([4.84124814e-05, 5.24411268e-05, 5.70397218e-05, 6.25745466e-05,
#        6.96276393e-05, 7.79682152e-05]), array([0.00018474, 0.00049566, 0.00105765, 0.00192366, 0.00318788,
#        0.0048107 ]), array([8.94351861e-09, 2.59931855e-08, 6.03278150e-08, 1.20372014e-07,
#        2.21964699e-07, 3.75081767e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '2.95', '3.15'): (array([4.84124814e-05, 5.24411271e-05, 5.70397215e-05, 6.25745461e-05,
#        6.96276399e-05, 7.79682178e-05]), array([0.00018474, 0.00049566, 0.00105761, 0.00192354, 0.00318763,
#        0.00481023]), array([8.94350102e-09, 2.59928295e-08, 6.03255540e-08, 1.20364855e-07,
#        2.21946903e-07, 3.75045215e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '3.05', '3.25'): (array([4.84124815e-05, 5.24411267e-05, 5.70397169e-05, 6.25745380e-05,
#        6.96276284e-05, 7.79682041e-05]), array([0.00018473, 0.00049564, 0.00105753, 0.00192337, 0.0031873 ,
#        0.0048097 ]), array([8.94338467e-09, 2.59917402e-08, 6.03211553e-08, 1.20353717e-07,
#        2.21924041e-07, 3.75003767e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '3.15', '3.35'): (array([4.84124804e-05, 5.24411221e-05, 5.70397010e-05, 6.25745126e-05,
#        6.96275923e-05, 7.79681552e-05]), array([0.00018473, 0.0004956 , 0.00105742, 0.00192315, 0.00318696,
#        0.00480921]), array([8.94302554e-09, 2.59896787e-08, 6.03150053e-08, 1.20340478e-07,
#        2.21900396e-07, 3.74965576e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '3.25', '3.45'): (array([4.84124749e-05, 5.24411068e-05, 5.70396642e-05, 6.25744608e-05,
#        6.96275163e-05, 7.79680469e-05]), array([0.00018471, 0.00049554, 0.0010573 , 0.00192295, 0.00318667,
#        0.00480884]), array([8.94233644e-09, 2.59868808e-08, 6.03082469e-08, 1.20327727e-07,
#        2.21880030e-07, 3.74936205e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '3.35', '3.55'): (array([4.84124593e-05, 5.24410730e-05, 5.70395986e-05, 6.25743694e-05,
#        6.96273790e-05, 7.79678501e-05]), array([0.00018469, 0.00049549, 0.0010572 , 0.00192279, 0.00318647,
#        0.00480863]), array([8.94138537e-09, 2.59838917e-08, 6.03020725e-08, 1.20317433e-07,
#        2.21865493e-07, 3.74918319e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '3.45', '3.65'): (array([4.84124249e-05, 5.24410091e-05, 5.70394908e-05, 6.25742121e-05,
#        6.96271455e-05, 7.79675115e-05]), array([0.00018467, 0.00049544, 0.00105711, 0.00192269, 0.00318637,
#        0.00480857]), array([8.94034447e-09, 2.59812118e-08, 6.02972732e-08, 1.20310586e-07,
#        2.21857796e-07, 3.74912478e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '3.55', '3.75'): (array([4.84123604e-05, 5.24408962e-05, 5.70393119e-05, 6.25739587e-05,
#        6.96267717e-05, 7.79669631e-05]), array([0.00018465, 0.0004954 , 0.00105706, 0.00192265, 0.00318637,
#        0.00480868]), array([8.93938803e-09, 2.59791635e-08, 6.02942599e-08, 1.20307528e-07,
#        2.21856966e-07, 3.74917892e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '3.65', '3.85'): (array([4.84122566e-05, 5.24407283e-05, 5.70390538e-05, 6.25736100e-05,
#        6.96262421e-05, 7.79661709e-05]), array([0.00018464, 0.00049538, 0.00105705, 0.00192267, 0.00318648,
#        0.00480892]), array([8.93864183e-09, 2.59779352e-08, 6.02932280e-08, 1.20308296e-07,
#        2.21862576e-07, 3.74933182e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '3.75', '3.95'): (array([4.84121094e-05, 5.24405163e-05, 5.70387360e-05, 6.25731756e-05,
#        6.96255377e-05, 7.79650946e-05]), array([0.00018463, 0.00049537, 0.00105707, 0.00192275, 0.00318667,
#        0.00480928]), array([8.93818025e-09, 2.59776083e-08, 6.02941637e-08, 1.20312577e-07,
#        2.21873676e-07, 3.74956236e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '3.85', '4.05'): (array([4.84119251e-05, 5.24402646e-05, 5.70383466e-05, 6.25726237e-05,
#        6.96245856e-05, 7.79635925e-05]), array([0.00018462, 0.00049539, 0.00105713, 0.00192288, 0.00318693,
#        0.00480973]), array([8.93803296e-09, 2.59781384e-08, 6.02967700e-08, 1.20319559e-07,
#        2.21888597e-07, 3.74984048e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '3.95', '4.15'): (array([4.84117165e-05, 5.24399688e-05, 5.70378457e-05, 6.25718848e-05,
#        6.96232695e-05, 7.79614312e-05]), array([0.00018463, 0.00049541, 0.0010572 , 0.00192304, 0.00318723,
#        0.00481025]), array([8.93818763e-09, 2.59793764e-08, 6.03005890e-08, 1.20328256e-07,
#        2.21905573e-07, 3.75013772e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '4.05', '4.25'): (array([4.84114849e-05, 5.24396048e-05, 5.70371965e-05, 6.25708558e-05,
#        6.96213774e-05, 7.79582853e-05]), array([0.00018464, 0.00049545, 0.0010573 , 0.00192322, 0.00318757,
#        0.00481082]), array([8.93859804e-09, 2.59811223e-08, 6.03051479e-08, 1.20337775e-07,
#        2.21923151e-07, 3.75043256e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '4.15', '4.35'): (array([4.84112232e-05, 5.24391413e-05, 5.70363426e-05, 6.25694465e-05,
#        6.96186293e-05, 7.79538042e-05]), array([0.00018465, 0.00049549, 0.0010574 , 0.00192342, 0.00318794,
#        0.00481145]), array([8.93919380e-09, 2.59831600e-08, 6.03100011e-08, 1.20347358e-07,
#        2.21940186e-07, 3.75070940e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '4.25', '4.45'): (array([4.84109080e-05, 5.24385440e-05, 5.70352114e-05, 6.25674736e-05,
#        6.96147458e-05, 7.79479215e-05]), array([0.00018467, 0.00049554, 0.0010575 , 0.00192363, 0.00318835,
#        0.00481214]), array([8.93989711e-09, 2.59852942e-08, 6.03147910e-08, 1.20356451e-07,
#        2.21955929e-07, 3.75095958e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '4.35', '4.55'): (array([4.84105231e-05, 5.24377664e-05, 5.70336610e-05, 6.25646580e-05,
#        6.96095963e-05, 7.79411987e-05]), array([0.00018468, 0.00049559, 0.00105761, 0.00192385, 0.00318878,
#        0.00481283]), array([8.94064066e-09, 2.59873793e-08, 6.03192786e-08, 1.20364734e-07,
#        2.21969987e-07, 3.75117939e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '4.45', '4.65'): (array([4.84100531e-05, 5.24367308e-05, 5.70314574e-05, 6.25607550e-05,
#        6.96036459e-05, 7.79350119e-05]), array([0.0001847 , 0.00049563, 0.00105772, 0.00192408, 0.00318923,
#        0.00481346]), array([8.94137172e-09, 2.59893178e-08, 6.03233249e-08, 1.20372050e-07,
#        2.21982225e-07, 3.75136827e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '4.55', '4.75'): (array([4.84094360e-05, 5.24352995e-05, 5.70283687e-05, 6.25556781e-05,
#        6.95981354e-05, 7.79314696e-05]), array([0.00018472, 0.00049568, 0.00105784, 0.00192434, 0.00318964,
#        0.00481388]), array([8.94205263e-09, 2.59910526e-08, 6.03268668e-08, 1.20378354e-07,
#        2.21992671e-07, 3.75152806e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '4.65', '4.85'): (array([4.84086192e-05, 5.24332860e-05, 5.70243570e-05, 6.25499099e-05,
#        6.95949281e-05, 7.79327372e-05]), array([0.00018473, 0.00049573, 0.00105797, 0.0019246 , 0.00318991,
#        0.00481397]), array([8.94266290e-09, 2.59925619e-08, 6.03299011e-08, 1.20383692e-07,
#        2.22001448e-07, 3.75166167e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '4.75', '4.95'): (array([4.84075371e-05, 5.24305011e-05, 5.70197724e-05, 6.25448338e-05,
#        6.95959278e-05, 7.79367770e-05]), array([0.00018475, 0.00049578, 0.0010581 , 0.00192483, 0.00318997,
#        0.00481387]), array([8.94319504e-09, 2.59938484e-08, 6.03324577e-08, 1.20388151e-07,
#        2.22008751e-07, 3.75177279e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'apr', '4.85', '5.05'): (array([4.84060720e-05, 5.24268862e-05, 5.70154742e-05, 6.25424052e-05,
#        6.95993599e-05, 7.73215304e-05]), array([0.00018476, 0.00049583, 0.00105821, 0.00192496, 0.0031899 ,
#        0.00485229]), array([8.94364960e-09, 2.59949294e-08, 6.03345846e-08, 1.20391844e-07,
#        2.22014797e-07, 3.75186475e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '2.05', '2.25'): (array([5.23442020e-05, 5.63753157e-05, 6.12945583e-05, 6.65843833e-05,
#        7.35814095e-05, 8.18216528e-05]), array([0.00015038, 0.00040504, 0.00086406, 0.00157993, 0.00262103,
#        0.00396132]), array([7.87135515e-09, 2.28344712e-08, 5.29624669e-08, 1.05198763e-07,
#        1.92859035e-07, 3.24121439e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '2.15', '2.35'): (array([5.23442020e-05, 5.63753157e-05, 6.12945583e-05, 6.65843833e-05,
#        7.35814095e-05, 8.18216528e-05]), array([0.00015038, 0.00040504, 0.00086406, 0.00157993, 0.00262103,
#        0.00396132]), array([7.87135515e-09, 2.28344712e-08, 5.29624669e-08, 1.05198763e-07,
#        1.92859035e-07, 3.24121439e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '2.25', '2.45'): (array([5.23442020e-05, 5.63753157e-05, 6.12945583e-05, 6.65843833e-05,
#        7.35814095e-05, 8.18216528e-05]), array([0.00015038, 0.00040504, 0.00086406, 0.00157993, 0.00262103,
#        0.00396132]), array([7.87135515e-09, 2.28344712e-08, 5.29624669e-08, 1.05198763e-07,
#        1.92859035e-07, 3.24121439e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '2.35', '2.55'): (array([5.23442020e-05, 5.63753157e-05, 6.12945583e-05, 6.65843833e-05,
#        7.35814095e-05, 8.18216528e-05]), array([0.00015038, 0.00040504, 0.00086406, 0.00157993, 0.00262103,
#        0.00396132]), array([7.87135515e-09, 2.28344712e-08, 5.29624669e-08, 1.05198763e-07,
#        1.92859034e-07, 3.24121436e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '2.45', '2.65'): (array([5.23442020e-05, 5.63753157e-05, 6.12945583e-05, 6.65843833e-05,
#        7.35814095e-05, 8.18216528e-05]), array([0.00015038, 0.00040504, 0.00086406, 0.00157993, 0.00262103,
#        0.00396132]), array([7.87135515e-09, 2.28344712e-08, 5.29624669e-08, 1.05198762e-07,
#        1.92859029e-07, 3.24121425e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '2.55', '2.75'): (array([5.23442020e-05, 5.63753157e-05, 6.12945583e-05, 6.65843833e-05,
#        7.35814096e-05, 8.18216530e-05]), array([0.00015038, 0.00040504, 0.00086406, 0.00157993, 0.00262103,
#        0.00396131]), array([7.87135515e-09, 2.28344712e-08, 5.29624663e-08, 1.05198740e-07,
#        1.92858911e-07, 3.24121093e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '2.65', '2.85'): (array([5.23442020e-05, 5.63753157e-05, 6.12945583e-05, 6.65843835e-05,
#        7.35814104e-05, 8.18216547e-05]), array([0.00015038, 0.00040504, 0.00086406, 0.00157993, 0.00262101,
#        0.00396128]), array([7.87135515e-09, 2.28344710e-08, 5.29624640e-08, 1.05198560e-07,
#        1.92857952e-07, 3.24118456e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '2.75', '2.95'): (array([5.23442020e-05, 5.63753157e-05, 6.12945584e-05, 6.65843841e-05,
#        7.35814128e-05, 8.18216599e-05]), array([0.00015038, 0.00040504, 0.00086406, 0.00157992, 0.00262096,
#        0.00396116]), array([7.87135508e-09, 2.28344701e-08, 5.29623679e-08, 1.05197672e-07,
#        1.92854184e-07, 3.24108804e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '2.85', '3.05'): (array([5.23442020e-05, 5.63753158e-05, 6.12945588e-05, 6.65843851e-05,
#        7.35814167e-05, 8.18216677e-05]), array([0.00015038, 0.00040504, 0.00086405, 0.00157987, 0.00262084,
#        0.00396091]), array([7.87135481e-09, 2.28344252e-08, 5.29617469e-08, 1.05194855e-07,
#        1.92845207e-07, 3.24088057e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '2.95', '3.15'): (array([5.23442020e-05, 5.63753161e-05, 6.12945590e-05, 6.65843843e-05,
#        7.35814180e-05, 8.18216709e-05]), array([0.00015038, 0.00040504, 0.00086402, 0.00157978, 0.00262064,
#        0.00396053]), array([7.87133974e-09, 2.28341207e-08, 5.29598142e-08, 1.05188761e-07,
#        1.92830144e-07, 3.24057283e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '3.05', '3.25'): (array([5.23442020e-05, 5.63753160e-05, 6.12945553e-05, 6.65843755e-05,
#        7.35814083e-05, 8.18216580e-05]), array([0.00015037, 0.00040502, 0.00086396, 0.00157964, 0.00262037,
#        0.00396011]), array([7.87124010e-09, 2.28331896e-08, 5.29560571e-08, 1.05179288e-07,
#        1.92810803e-07, 3.24022407e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '3.15', '3.35'): (array([5.23442007e-05, 5.63753118e-05, 6.12945411e-05, 6.65843492e-05,
#        7.35813744e-05, 8.18216106e-05]), array([0.00015037, 0.00040499, 0.00086387, 0.00157947, 0.0026201 ,
#        0.00395972]), array([7.87093273e-09, 2.28314289e-08, 5.29508072e-08, 1.05168031e-07,
#        1.92790802e-07, 3.23990262e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '3.25', '3.45'): (array([5.23441945e-05, 5.63752973e-05, 6.12945076e-05, 6.65842954e-05,
#        7.35813016e-05, 8.18215076e-05]), array([0.00015036, 0.00040495, 0.00086378, 0.00157931, 0.00261987,
#        0.00395942]), array([7.87034341e-09, 2.28290407e-08, 5.29450386e-08, 1.05157186e-07,
#        1.92773562e-07, 3.23965511e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '3.35', '3.55'): (array([5.23441774e-05, 5.63752648e-05, 6.12944459e-05, 6.65842016e-05,
#        7.35811761e-05, 8.18213210e-05]), array([0.00015034, 0.0004049 , 0.0008637 , 0.00157918, 0.00261971,
#        0.00395924]), array([7.86953039e-09, 2.28264889e-08, 5.29397655e-08, 1.05148420e-07,
#        1.92761231e-07, 3.23950386e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '3.45', '3.65'): (array([5.23441409e-05, 5.63752037e-05, 6.12943422e-05, 6.65840436e-05,
#        7.35809696e-05, 8.18209981e-05]), array([0.00015033, 0.00040486, 0.00086363, 0.0015791 , 0.00261963,
#        0.0039592 ]), array([7.86864032e-09, 2.28241994e-08, 5.29356613e-08, 1.05142574e-07,
#        1.92754665e-07, 3.23945365e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '3.55', '3.75'): (array([5.23440730e-05, 5.63750914e-05, 6.12941652e-05, 6.65837890e-05,
#        7.35806287e-05, 8.18204838e-05]), array([0.00015031, 0.00040483, 0.00086359, 0.00157906, 0.00261963,
#        0.00395927]), array([7.86782171e-09, 2.28224461e-08, 5.29330748e-08, 1.05139934e-07,
#        1.92753878e-07, 3.23949767e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '3.65', '3.85'): (array([5.23439637e-05, 5.63749228e-05, 6.12939154e-05, 6.65834403e-05,
#        7.35801382e-05, 8.18197587e-05]), array([0.0001503 , 0.00040481, 0.00086358, 0.00157908, 0.00261971,
#        0.00395946]), array([7.86718205e-09, 2.28213908e-08, 5.29321750e-08, 1.05140538e-07,
#        1.92758520e-07, 3.23962447e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '3.75', '3.95'): (array([5.23438101e-05, 5.63747148e-05, 6.12936209e-05, 6.65830146e-05,
#        7.35795171e-05, 8.18187879e-05]), array([0.00015029, 0.00040481, 0.0008636 , 0.00157914, 0.00261986,
#        0.00395975]), array([7.86678517e-09, 2.28211049e-08, 5.29329561e-08, 1.05144130e-07,
#        1.92767806e-07, 3.23981663e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '3.85', '4.05'): (array([5.23436208e-05, 5.63744741e-05, 6.12932745e-05, 6.65824834e-05,
#        7.35786944e-05, 8.18174519e-05]), array([0.00015029, 0.00040482, 0.00086364, 0.00157924, 0.00262006,
#        0.00396009]), array([7.86665687e-09, 2.28215513e-08, 5.29351640e-08, 1.05150021e-07,
#        1.92780321e-07, 3.24004876e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '3.95', '4.15'): (array([5.23434079e-05, 5.63741898e-05, 6.12928440e-05, 6.65817797e-05,
#        7.35775677e-05, 8.18155455e-05]), array([0.00015029, 0.00040484, 0.0008637 , 0.00157937, 0.00262029,
#        0.00396049]), array([7.86678694e-09, 2.28226020e-08, 5.29384051e-08, 1.05157361e-07,
#        1.92794561e-07, 3.24029676e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '4.05', '4.25'): (array([5.23431739e-05, 5.63738539e-05, 6.12922992e-05, 6.65808141e-05,
#        7.35760554e-05, 8.18127595e-05]), array([0.0001503 , 0.00040487, 0.00086377, 0.00157952, 0.00262054,
#        0.00396093]), array([7.86713568e-09, 2.28240856e-08, 5.29422747e-08, 1.05165396e-07,
#        1.92809303e-07, 3.24054261e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '4.15', '4.35'): (array([5.23429118e-05, 5.63734522e-05, 6.12915923e-05, 6.65795069e-05,
#        7.35739523e-05, 8.18088099e-05]), array([0.00015031, 0.0004049 , 0.00086384, 0.00157967, 0.00262081,
#        0.0039614 ]), array([7.86764256e-09, 2.28258167e-08, 5.29463921e-08, 1.05173479e-07,
#        1.92823577e-07, 3.24077325e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '4.25', '4.45'): (array([5.23425986e-05, 5.63729367e-05, 6.12906276e-05, 6.65776911e-05,
#        7.35709329e-05, 8.18036393e-05]), array([0.00015032, 0.00040494, 0.00086392, 0.00157983, 0.0026211 ,
#        0.0039619 ]), array([7.86824083e-09, 2.28276284e-08, 5.29504520e-08, 1.05181142e-07,
#        1.92836754e-07, 3.24098145e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '4.35', '4.55'): (array([5.23422223e-05, 5.63722504e-05, 6.12893105e-05, 6.65751157e-05,
#        7.35666487e-05, 8.17976390e-05]), array([0.00015034, 0.00040498, 0.000864  , 0.00157999, 0.00262141,
#        0.00396242]), array([7.86887288e-09, 2.28293966e-08, 5.29542516e-08, 1.05188115e-07,
#        1.92848511e-07, 3.24116415e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '4.45', '4.65'): (array([5.23417723e-05, 5.63713562e-05, 6.12875237e-05, 6.65715565e-05,
#        7.35610461e-05, 8.17918223e-05]), array([0.00015035, 0.00040501, 0.00086409, 0.00158017, 0.00262175,
#        0.00396289]), array([7.86949379e-09, 2.28310388e-08, 5.29576747e-08, 1.05194267e-07,
#        1.92858737e-07, 3.24132103e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '4.55', '4.75'): (array([5.23411904e-05, 5.63701672e-05, 6.12850306e-05, 6.65669131e-05,
#        7.35547170e-05, 8.17877692e-05]), array([0.00015036, 0.00040505, 0.00086417, 0.00158036, 0.0026221 ,
#        0.00396325]), array([7.87007154e-09, 2.28325068e-08, 5.29606681e-08, 1.05199562e-07,
#        1.92867457e-07, 3.24145362e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '4.65', '4.85'): (array([5.23404213e-05, 5.63685430e-05, 6.12815634e-05, 6.65615681e-05,
#        7.35490448e-05, 8.17872719e-05]), array([0.00015037, 0.00040508, 0.00086426, 0.00158055, 0.0026224 ,
#        0.00396341]), array([7.87058879e-09, 2.28337829e-08, 5.29632292e-08, 1.05204042e-07,
#        1.92874776e-07, 3.24156435e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '4.75', '4.95'): (array([5.23394094e-05, 5.63662792e-05, 6.12770704e-05, 6.65566789e-05,
#        7.35461442e-05, 8.17890239e-05]), array([0.00015038, 0.00040512, 0.00086436, 0.00158072, 0.00262258,
#        0.00396344]), array([7.87103940e-09, 2.28348697e-08, 5.29653849e-08, 1.05207780e-07,
#        1.92880857e-07, 3.24165626e-07])), ('1.5', '1.0', '1.0', '1.01', '2212', 'jul', '4.85', '5.05'): (array([5.23380725e-05, 5.63631547e-05, 6.12719748e-05, 6.65539319e-05,
#        7.35481657e-05, 8.12887507e-05]), array([0.0001504 , 0.00040515, 0.00086446, 0.00158084, 0.00262258,
#        0.00398792]), array([7.87142404e-09, 2.28357819e-08, 5.29671778e-08, 1.05210872e-07,
#        1.92885886e-07, 3.24173222e-07])), ('3.5', '1.0', '1.0', '1.0', '2212', 'jan', '2.05', 'inf'): (array([1.70330846e-04, 1.06876844e-04, 6.73452788e-05, 5.14953703e-05,
#        4.54814038e-05, 4.36471197e-05]), array([1.92789492e-07, 1.09867165e-06, 4.61357152e-06, 1.48584873e-05,
#        3.75955746e-05, 7.85354295e-05]), array([3.28379973e-11, 1.17422559e-10, 3.10702261e-10, 7.65143305e-10,
#        1.70989951e-09, 3.42784530e-09])), ('3.5', '1.0', '1.0', '1.0', '2212', 'apr', '2.05', 'inf'): (array([1.81360041e-04, 1.16842377e-04, 7.40765220e-05, 5.64311209e-05,
#        4.95714652e-05, 4.74196646e-05]), array([1.82645612e-07, 1.01962710e-06, 4.21234605e-06, 1.35133728e-05,
#        3.42176841e-05, 7.14801651e-05]), array([3.31246157e-11, 1.19135654e-10, 3.12035945e-10, 7.62574776e-10,
#        1.69622074e-09, 3.38956545e-09])), ('3.5', '1.0', '1.0', '1.0', '2212', 'jul', '2.05', 'inf'): (array([1.94752946e-04, 1.32540815e-04, 8.43891954e-05, 6.38435911e-05,
#        5.51546064e-05, 5.20567257e-05]), array([1.53194674e-07, 8.37075458e-07, 3.36866328e-06, 1.06923952e-05,
#        2.72836730e-05, 5.75363291e-05]), array([2.98351142e-11, 1.10946664e-10, 2.84278784e-10, 6.82640909e-10,
#        1.50482024e-09, 2.99515291e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '2.05', '2.25'): (array([1.70330846e-04, 1.06876844e-04, 6.73452788e-05, 5.14953703e-05,
#        4.54814038e-05, 4.36471197e-05]), array([1.92789492e-07, 1.09867165e-06, 4.61357152e-06, 1.48584873e-05,
#        3.75955746e-05, 7.85354295e-05]), array([3.28379973e-11, 1.17422559e-10, 3.10702261e-10, 7.65143305e-10,
#        1.70989951e-09, 3.42784530e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '2.15', '2.35'): (array([1.70330846e-04, 1.06876844e-04, 6.73452788e-05, 5.14953703e-05,
#        4.54814038e-05, 4.36471197e-05]), array([1.92789492e-07, 1.09867165e-06, 4.61357152e-06, 1.48584873e-05,
#        3.75955746e-05, 7.85354295e-05]), array([3.28379973e-11, 1.17422559e-10, 3.10702261e-10, 7.65143305e-10,
#        1.70989951e-09, 3.42784530e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '2.25', '2.45'): (array([1.70330846e-04, 1.06876844e-04, 6.73452788e-05, 5.14953703e-05,
#        4.54814038e-05, 4.36471197e-05]), array([1.92789492e-07, 1.09867165e-06, 4.61357152e-06, 1.48584873e-05,
#        3.75955746e-05, 7.85354295e-05]), array([3.28379973e-11, 1.17422559e-10, 3.10702261e-10, 7.65143305e-10,
#        1.70989951e-09, 3.42784530e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '2.35', '2.55'): (array([1.70330846e-04, 1.06876844e-04, 6.73452788e-05, 5.14953703e-05,
#        4.54814038e-05, 4.36471197e-05]), array([1.92789492e-07, 1.09867165e-06, 4.61357152e-06, 1.48584873e-05,
#        3.75955746e-05, 7.85354295e-05]), array([3.28379973e-11, 1.17422559e-10, 3.10702261e-10, 7.65143305e-10,
#        1.70989951e-09, 3.42784530e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '2.45', '2.65'): (array([1.70330846e-04, 1.06876844e-04, 6.73452788e-05, 5.14953703e-05,
#        4.54814038e-05, 4.36471197e-05]), array([1.92789492e-07, 1.09867165e-06, 4.61357152e-06, 1.48584873e-05,
#        3.75955746e-05, 7.85354295e-05]), array([3.28379973e-11, 1.17422559e-10, 3.10702261e-10, 7.65143305e-10,
#        1.70989951e-09, 3.42784530e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '2.55', '2.75'): (array([1.70330846e-04, 1.06876844e-04, 6.73452788e-05, 5.14953703e-05,
#        4.54814038e-05, 4.36471197e-05]), array([1.92789492e-07, 1.09867165e-06, 4.61357152e-06, 1.48584873e-05,
#        3.75955746e-05, 7.85354295e-05]), array([3.28379973e-11, 1.17422559e-10, 3.10702261e-10, 7.65143305e-10,
#        1.70989951e-09, 3.42784530e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '2.65', '2.85'): (array([1.70330846e-04, 1.06876844e-04, 6.73452788e-05, 5.14953703e-05,
#        4.54814038e-05, 4.36471197e-05]), array([1.92789492e-07, 1.09867165e-06, 4.61357152e-06, 1.48584873e-05,
#        3.75955746e-05, 7.85354295e-05]), array([3.28379973e-11, 1.17422559e-10, 3.10702261e-10, 7.65143305e-10,
#        1.70989951e-09, 3.42784530e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '2.75', '2.95'): (array([1.70330846e-04, 1.06876844e-04, 6.73452788e-05, 5.14953703e-05,
#        4.54814038e-05, 4.36471197e-05]), array([1.92789492e-07, 1.09867165e-06, 4.61357152e-06, 1.48584873e-05,
#        3.75955746e-05, 7.85354295e-05]), array([3.28379973e-11, 1.17422559e-10, 3.10702261e-10, 7.65143305e-10,
#        1.70989951e-09, 3.42784530e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '2.85', '3.05'): (array([1.70330846e-04, 1.06876844e-04, 6.73452788e-05, 5.14953703e-05,
#        4.54814038e-05, 4.36471197e-05]), array([1.92789492e-07, 1.09867165e-06, 4.61357152e-06, 1.48584873e-05,
#        3.75955745e-05, 7.85354288e-05]), array([3.28379973e-11, 1.17422559e-10, 3.10702261e-10, 7.65143304e-10,
#        1.70989950e-09, 3.42784526e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '2.95', '3.15'): (array([1.70330846e-04, 1.06876844e-04, 6.73452788e-05, 5.14953703e-05,
#        4.54814038e-05, 4.36471197e-05]), array([1.92789492e-07, 1.09867165e-06, 4.61357152e-06, 1.48584872e-05,
#        3.75955738e-05, 7.85354251e-05]), array([3.28379973e-11, 1.17422559e-10, 3.10702261e-10, 7.65143301e-10,
#        1.70989947e-09, 3.42784510e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '3.05', '3.25'): (array([1.70330846e-04, 1.06876844e-04, 6.73452788e-05, 5.14953703e-05,
#        4.54814038e-05, 4.36471197e-05]), array([1.92789492e-07, 1.09867165e-06, 4.61357150e-06, 1.48584864e-05,
#        3.75955506e-05, 7.85352455e-05]), array([3.28379973e-11, 1.17422559e-10, 3.10702259e-10, 7.65143259e-10,
#        1.70989842e-09, 3.42783726e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '3.15', '3.35'): (array([1.70330846e-04, 1.06876844e-04, 6.73452788e-05, 5.14953701e-05,
#        4.54814033e-05, 4.36471188e-05]), array([1.92789492e-07, 1.09867165e-06, 4.61357135e-06, 1.48584678e-05,
#        3.75953364e-05, 7.85340954e-05]), array([3.28379973e-11, 1.17422559e-10, 3.10702249e-10, 7.65142299e-10,
#        1.70988866e-09, 3.42778699e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '3.25', '3.45'): (array([1.70330846e-04, 1.06876844e-04, 6.73452785e-05, 5.14953685e-05,
#        4.54814002e-05, 4.36471146e-05]), array([1.92789492e-07, 1.09867158e-06, 4.61356522e-06, 1.48583420e-05,
#        3.75944708e-05, 7.85306699e-05]), array([3.28379973e-11, 1.17422551e-10, 3.10701835e-10, 7.65135798e-10,
#        1.70984917e-09, 3.42763715e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '3.35', '3.55'): (array([1.70330846e-04, 1.06876844e-04, 6.73452753e-05, 5.14953610e-05,
#        4.54813898e-05, 4.36471018e-05]), array([1.92789489e-07, 1.09867017e-06, 4.61352211e-06, 1.48579083e-05,
#        3.75923899e-05, 7.85242348e-05]), array([3.28379969e-11, 1.17422400e-10, 3.10698917e-10, 7.65113351e-10,
#        1.70975414e-09, 3.42735527e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '3.45', '3.65'): (array([1.70330846e-04, 1.06876839e-04, 6.73452610e-05, 5.14953386e-05,
#        4.54813638e-05, 4.36470724e-05]), array([1.92789417e-07, 1.09866108e-06, 4.61337740e-06, 1.48569663e-05,
#        3.75889271e-05, 7.85154101e-05]), array([3.28379845e-11, 1.17421423e-10, 3.10689105e-10, 7.65064510e-10,
#        1.70959567e-09, 3.42696779e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '3.55', '3.75'): (array([1.70330846e-04, 1.06876817e-04, 6.73452202e-05, 5.14952890e-05,
#        4.54813131e-05, 4.36470183e-05]), array([1.92788697e-07, 1.09863032e-06, 4.61307026e-06, 1.48554988e-05,
#        3.75845258e-05, 7.85057732e-05]), array([3.28378618e-11, 1.17418112e-10, 3.10668232e-10, 7.64988203e-10,
#        1.70939359e-09, 3.42654292e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '3.65', '3.85'): (array([1.70330841e-04, 1.06876755e-04, 6.73451342e-05, 5.14952013e-05,
#        4.54812301e-05, 4.36469315e-05]), array([1.92785472e-07, 1.09856306e-06, 4.61259978e-06, 1.48537161e-05,
#        3.75799698e-05, 7.84969714e-05]), array([3.28373116e-11, 1.17410855e-10, 3.10636151e-10, 7.64895101e-10,
#        1.70918325e-09, 3.42615194e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '3.75', '3.95'): (array([1.70330825e-04, 1.06876624e-04, 6.73449865e-05, 5.14950653e-05,
#        4.54811048e-05, 4.36468023e-05]), array([1.92777014e-07, 1.09845734e-06, 4.61203885e-06, 1.48519396e-05,
#        3.75760064e-05, 7.84902155e-05]), array([3.28358678e-11, 1.17399412e-10, 3.10597694e-10, 7.64801598e-10,
#        1.70899828e-09, 3.42584691e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '3.85', '4.05'): (array([1.70330781e-04, 1.06876398e-04, 6.73447649e-05, 5.14948726e-05,
#        4.54809304e-05, 4.36466294e-05]), array([1.92761615e-07, 1.09832683e-06, 4.61148583e-06, 1.48504419e-05,
#        3.75731319e-05, 7.84861848e-05]), array([3.28332364e-11, 1.17385215e-10, 3.10559429e-10, 7.64721613e-10,
#        1.70886100e-09, 3.42565742e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '3.95', '4.15'): (array([1.70330690e-04, 1.06876059e-04, 6.73444622e-05, 5.14946226e-05,
#        4.54807125e-05, 4.36464255e-05]), array([1.92740289e-07, 1.09819252e-06, 4.61101954e-06, 1.48493930e-05,
#        3.75716024e-05, 7.84851200e-05]), array([3.28295864e-11, 1.17370489e-10, 3.10526632e-10, 7.64663888e-10,
#        1.70878325e-09, 3.42559494e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '4.05', '4.25'): (array([1.70330531e-04, 1.06875601e-04, 6.73440834e-05, 5.14943248e-05,
#        4.54804677e-05, 4.36461998e-05]), array([1.92716324e-07, 1.09807484e-06, 4.61069568e-06, 1.48488919e-05,
#        3.75715023e-05, 7.84869226e-05]), array([3.28254738e-11, 1.17357408e-10, 3.10503075e-10, 7.64633661e-10,
#        1.70876950e-09, 3.42565590e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '4.15', '4.35'): (array([1.70330283e-04, 1.06875031e-04, 6.73436418e-05, 5.14939925e-05,
#        4.54802073e-05, 4.36459568e-05]), array([1.92693330e-07, 1.09798811e-06, 4.61054438e-06, 1.48489600e-05,
#        3.75727302e-05, 7.84911451e-05]), array([3.28215094e-11, 1.17347513e-10, 3.10490849e-10, 7.64632233e-10,
#        1.70881555e-09, 3.42582113e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '4.25', '4.45'): (array([1.70329935e-04, 1.06874364e-04, 6.73431513e-05, 5.14936367e-05,
#        4.54799288e-05, 4.36456953e-05]), array([1.92674400e-07, 1.09794100e-06, 4.61057098e-06, 1.48495408e-05,
#        3.75750299e-05, 7.84971120e-05]), array([3.28182180e-11, 1.17341746e-10, 3.10490379e-10, 7.64656859e-10,
#        1.70890969e-09, 3.42606103e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '4.35', '4.55'): (array([1.70329498e-04, 1.06873620e-04, 6.73426252e-05, 5.14932631e-05,
#        4.54796313e-05, 4.36454050e-05]), array([1.92661816e-07, 1.09793680e-06, 4.61075924e-06, 1.48505287e-05,
#        3.75780790e-05, 7.85041441e-05]), array([3.28159904e-11, 1.17340481e-10, 3.10500631e-10, 7.64702182e-10,
#        1.70903718e-09, 3.42634516e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '4.45', '4.65'): (array([1.70328993e-04, 1.06872818e-04, 6.73420791e-05, 5.14928790e-05,
#        4.54793137e-05, 4.36450742e-05]), array([1.92656632e-07, 1.09797211e-06, 4.61107270e-06, 1.48517870e-05,
#        3.75815441e-05, 7.85116309e-05]), array([3.28150100e-11, 1.17343374e-10, 3.10519223e-10, 7.64761268e-10,
#        1.70918283e-09, 3.42664596e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '4.55', '4.75'): (array([1.70328435e-04, 1.06871978e-04, 6.73415285e-05, 5.14924879e-05,
#        4.54789742e-05, 4.36446889e-05]), array([1.92658816e-07, 1.09803906e-06, 4.61146733e-06, 1.48531803e-05,
#        3.75851300e-05, 7.85190853e-05]), array([3.28152747e-11, 1.17349606e-10, 3.10543259e-10, 7.64827208e-10,
#        1.70933316e-09, 3.42694105e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '4.65', '4.85'): (array([1.70327830e-04, 1.06871122e-04, 6.73409785e-05, 5.14920814e-05,
#        4.54786019e-05, 4.36442245e-05]), array([1.92667490e-07, 1.09812797e-06, 4.61190246e-06, 1.48546019e-05,
#        3.75886291e-05, 7.85262150e-05]), array([3.28166354e-11, 1.17358168e-10, 3.10570024e-10, 7.64894371e-10,
#        1.70947830e-09, 3.42721576e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '4.75', '4.95'): (array([1.70327182e-04, 1.06870276e-04, 6.73404277e-05, 5.14916510e-05,
#        4.54781737e-05, 4.36436375e-05]), array([1.92681058e-07, 1.09822868e-06, 4.61234417e-06, 1.48559743e-05,
#        3.75919222e-05, 7.85329155e-05]), array([3.28188215e-11, 1.17368002e-10, 3.10597229e-10, 7.64958642e-10,
#        1.70961197e-09, 3.42746210e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jan', '4.85', '5.05'): (array([1.70326502e-04, 1.06869463e-04, 6.73398862e-05, 5.14912010e-05,
#        4.54776511e-05, 4.36428627e-05]), array([1.92697669e-07, 1.09833244e-06, 4.61276715e-06, 1.48572460e-05,
#        3.75949686e-05, 7.85392325e-05]), array([3.28215198e-11, 1.17378198e-10, 3.10623215e-10, 7.65017440e-10,
#        1.70973086e-09, 3.42767694e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'apr', '2.05', '2.25'): (array([1.81360041e-04, 1.16842377e-04, 7.40765220e-05, 5.64311209e-05,
#        4.95714652e-05, 4.74196646e-05]), array([1.82645612e-07, 1.01962710e-06, 4.21234605e-06, 1.35133728e-05,
#        3.42176841e-05, 7.14801651e-05]), array([3.31246157e-11, 1.19135654e-10, 3.12035945e-10, 7.62574776e-10,
#        1.69622074e-09, 3.38956545e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'apr', '2.15', '2.35'): (array([1.81360041e-04, 1.16842377e-04, 7.40765220e-05, 5.64311209e-05,
#        4.95714652e-05, 4.74196646e-05]), array([1.82645612e-07, 1.01962710e-06, 4.21234605e-06, 1.35133728e-05,
#        3.42176841e-05, 7.14801651e-05]), array([3.31246157e-11, 1.19135654e-10, 3.12035945e-10, 7.62574776e-10,
#        1.69622074e-09, 3.38956545e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'apr', '2.25', '2.45'): (array([1.81360041e-04, 1.16842377e-04, 7.40765220e-05, 5.64311209e-05,
#        4.95714652e-05, 4.74196646e-05]), array([1.82645612e-07, 1.01962710e-06, 4.21234605e-06, 1.35133728e-05,
#        3.42176841e-05, 7.14801651e-05]), array([3.31246157e-11, 1.19135654e-10, 3.12035945e-10, 7.62574776e-10,
#        1.69622074e-09, 3.38956545e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'apr', '2.35', '2.55'): (array([1.81360041e-04, 1.16842377e-04, 7.40765220e-05, 5.64311209e-05,
# ...
#        4.95709812e-05, 4.74191769e-05]), array([1.82620459e-07, 1.01932230e-06, 4.21053253e-06, 1.35064076e-05,
#        3.41982399e-05, 7.14374848e-05]), array([3.31200444e-11, 1.19099575e-10, 3.11899371e-10, 7.62174729e-10,
#        1.69524031e-09, 3.38750673e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'apr', '3.95', '4.15'): (array([1.81359912e-04, 1.16841575e-04, 7.40756822e-05, 5.64303460e-05,
#        4.95707594e-05, 4.74189727e-05]), array([1.82601238e-07, 1.01920370e-06, 4.21012752e-06, 1.35055021e-05,
#        3.41969238e-05, 7.14365838e-05]), array([3.31165446e-11, 1.19085366e-10, 3.11868068e-10, 7.62120157e-10,
#        1.69516748e-09, 3.38744942e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'apr', '4.05', '4.25'): (array([1.81359777e-04, 1.16841112e-04, 7.40752970e-05, 5.64300400e-05,
#        4.95705096e-05, 4.74187446e-05]), array([1.82579650e-07, 1.01909980e-06, 4.20984643e-06, 1.35050721e-05,
#        3.41968505e-05, 7.14381787e-05]), array([3.31126046e-11, 1.19072754e-10, 3.11845625e-10, 7.62091756e-10,
#        1.69515531e-09, 3.38750875e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'apr', '4.15', '4.35'): (array([1.81359562e-04, 1.16840539e-04, 7.40748466e-05, 5.64296986e-05,
#        4.95702428e-05, 4.74184972e-05]), array([1.82558946e-07, 1.01902326e-06, 4.20971565e-06, 1.35051361e-05,
#        3.41979317e-05, 7.14418771e-05]), array([3.31088104e-11, 1.19063227e-10, 3.11834041e-10, 7.62090759e-10,
#        1.69519978e-09, 3.38766645e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'apr', '4.25', '4.45'): (array([1.81359255e-04, 1.16839870e-04, 7.40743481e-05, 5.64293320e-05,
#        4.95699566e-05, 4.74182313e-05]), array([1.82541913e-07, 1.01898174e-06, 4.20973966e-06, 1.35056451e-05,
#        3.41999434e-05, 7.14470858e-05]), array([3.31056653e-11, 1.19057695e-10, 3.11833721e-10, 7.62114532e-10,
#        1.69528971e-09, 3.38789444e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'apr', '4.35', '4.55'): (array([1.81358867e-04, 1.16839123e-04, 7.40738176e-05, 5.64289458e-05,
#        4.95696496e-05, 4.74179367e-05]), array([1.82530608e-07, 1.01897819e-06, 4.20990409e-06, 1.35065070e-05,
#        3.42026042e-05, 7.14532119e-05]), array([3.31035443e-11, 1.19056518e-10, 3.11843668e-10, 7.62157954e-10,
#        1.69541111e-09, 3.38816388e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'apr', '4.45', '4.65'): (array([1.81358416e-04, 1.16838315e-04, 7.40732643e-05, 5.64285470e-05,
#        4.95693203e-05, 4.74176000e-05]), array([1.82525986e-07, 1.01900958e-06, 4.21017747e-06, 1.35076029e-05,
#        3.42056243e-05, 7.14597262e-05]), array([3.31026237e-11, 1.19059363e-10, 3.11861588e-10, 7.62214407e-10,
#        1.69554954e-09, 3.38844871e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'apr', '4.55', '4.75'): (array([1.81357915e-04, 1.16837463e-04, 7.40726968e-05, 5.64281394e-05,
#        4.95689664e-05, 4.74172032e-05]), array([1.82528015e-07, 1.01906895e-06, 4.21052174e-06, 1.35088152e-05,
#        3.42087471e-05, 7.14662109e-05]), array([3.31029002e-11, 1.19065432e-10, 3.11884700e-10, 7.62277307e-10,
#        1.69569224e-09, 3.38872784e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'apr', '4.65', '4.85'): (array([1.81357369e-04, 1.16836598e-04, 7.40721303e-05, 5.64277150e-05,
#        4.95685776e-05, 4.74167266e-05]), array([1.82535892e-07, 1.01914765e-06, 4.21090086e-06, 1.35100508e-05,
#        3.42117920e-05, 7.14724046e-05]), array([3.31042290e-11, 1.19073744e-10, 3.11910397e-10, 7.62341297e-10,
#        1.69582987e-09, 3.38898747e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'apr', '4.75', '4.95'): (array([1.81356780e-04, 1.16835742e-04, 7.40715762e-05, 5.64272660e-05,
#        4.95681319e-05, 4.74161346e-05]), array([1.82548173e-07, 1.01923672e-06, 4.21128463e-06, 1.35112426e-05,
#        3.42146550e-05, 7.14782039e-05]), array([3.31063489e-11, 1.19083278e-10, 3.11936490e-10, 7.62402479e-10,
#        1.69595653e-09, 3.38922014e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'apr', '4.85', '5.05'): (array([1.81356154e-04, 1.16834917e-04, 7.40710329e-05, 5.64267958e-05,
#        4.95675918e-05, 4.74153634e-05]), array([1.82563189e-07, 1.01932844e-06, 4.21165178e-06, 1.35123465e-05,
#        3.42172996e-05, 7.14836447e-05]), array([3.31089577e-11, 1.19093153e-10, 3.11961398e-10, 7.62458419e-10,
#        1.69606914e-09, 3.38942299e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '2.05', '2.25'): (array([1.94752946e-04, 1.32540815e-04, 8.43891954e-05, 6.38435911e-05,
#        5.51546064e-05, 5.20567257e-05]), array([1.53194674e-07, 8.37075458e-07, 3.36866328e-06, 1.06923952e-05,
#        2.72836730e-05, 5.75363291e-05]), array([2.98351142e-11, 1.10946664e-10, 2.84278784e-10, 6.82640909e-10,
#        1.50482024e-09, 2.99515291e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '2.15', '2.35'): (array([1.94752946e-04, 1.32540815e-04, 8.43891954e-05, 6.38435911e-05,
#        5.51546064e-05, 5.20567257e-05]), array([1.53194674e-07, 8.37075458e-07, 3.36866328e-06, 1.06923952e-05,
#        2.72836730e-05, 5.75363291e-05]), array([2.98351142e-11, 1.10946664e-10, 2.84278784e-10, 6.82640909e-10,
#        1.50482024e-09, 2.99515291e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '2.25', '2.45'): (array([1.94752946e-04, 1.32540815e-04, 8.43891954e-05, 6.38435911e-05,
#        5.51546064e-05, 5.20567257e-05]), array([1.53194674e-07, 8.37075458e-07, 3.36866328e-06, 1.06923952e-05,
#        2.72836730e-05, 5.75363291e-05]), array([2.98351142e-11, 1.10946664e-10, 2.84278784e-10, 6.82640909e-10,
#        1.50482024e-09, 2.99515291e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '2.35', '2.55'): (array([1.94752946e-04, 1.32540815e-04, 8.43891954e-05, 6.38435911e-05,
#        5.51546064e-05, 5.20567257e-05]), array([1.53194674e-07, 8.37075458e-07, 3.36866328e-06, 1.06923952e-05,
#        2.72836730e-05, 5.75363291e-05]), array([2.98351142e-11, 1.10946664e-10, 2.84278784e-10, 6.82640909e-10,
#        1.50482024e-09, 2.99515291e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '2.45', '2.65'): (array([1.94752946e-04, 1.32540815e-04, 8.43891954e-05, 6.38435911e-05,
#        5.51546064e-05, 5.20567257e-05]), array([1.53194674e-07, 8.37075458e-07, 3.36866328e-06, 1.06923952e-05,
#        2.72836730e-05, 5.75363291e-05]), array([2.98351142e-11, 1.10946664e-10, 2.84278784e-10, 6.82640909e-10,
#        1.50482024e-09, 2.99515291e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '2.55', '2.75'): (array([1.94752946e-04, 1.32540815e-04, 8.43891954e-05, 6.38435911e-05,
#        5.51546064e-05, 5.20567257e-05]), array([1.53194674e-07, 8.37075458e-07, 3.36866328e-06, 1.06923952e-05,
#        2.72836730e-05, 5.75363291e-05]), array([2.98351142e-11, 1.10946664e-10, 2.84278784e-10, 6.82640909e-10,
#        1.50482024e-09, 2.99515291e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '2.65', '2.85'): (array([1.94752946e-04, 1.32540815e-04, 8.43891954e-05, 6.38435911e-05,
#        5.51546064e-05, 5.20567257e-05]), array([1.53194674e-07, 8.37075458e-07, 3.36866328e-06, 1.06923952e-05,
#        2.72836730e-05, 5.75363291e-05]), array([2.98351142e-11, 1.10946664e-10, 2.84278784e-10, 6.82640909e-10,
#        1.50482024e-09, 2.99515291e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '2.75', '2.95'): (array([1.94752946e-04, 1.32540815e-04, 8.43891954e-05, 6.38435911e-05,
#        5.51546064e-05, 5.20567257e-05]), array([1.53194674e-07, 8.37075458e-07, 3.36866328e-06, 1.06923952e-05,
#        2.72836730e-05, 5.75363291e-05]), array([2.98351142e-11, 1.10946664e-10, 2.84278784e-10, 6.82640909e-10,
#        1.50482024e-09, 2.99515291e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '2.85', '3.05'): (array([1.94752946e-04, 1.32540815e-04, 8.43891954e-05, 6.38435911e-05,
#        5.51546064e-05, 5.20567257e-05]), array([1.53194674e-07, 8.37075458e-07, 3.36866328e-06, 1.06923952e-05,
#        2.72836729e-05, 5.75363286e-05]), array([2.98351142e-11, 1.10946664e-10, 2.84278784e-10, 6.82640909e-10,
#        1.50482024e-09, 2.99515288e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '2.95', '3.15'): (array([1.94752946e-04, 1.32540815e-04, 8.43891954e-05, 6.38435911e-05,
#        5.51546064e-05, 5.20567257e-05]), array([1.53194674e-07, 8.37075458e-07, 3.36866328e-06, 1.06923952e-05,
#        2.72836724e-05, 5.75363261e-05]), array([2.98351142e-11, 1.10946664e-10, 2.84278784e-10, 6.82640906e-10,
#        1.50482021e-09, 2.99515275e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '3.05', '3.25'): (array([1.94752946e-04, 1.32540815e-04, 8.43891954e-05, 6.38435911e-05,
#        5.51546063e-05, 5.20567257e-05]), array([1.53194674e-07, 8.37075458e-07, 3.36866327e-06, 1.06923946e-05,
#        2.72836568e-05, 5.75362036e-05]), array([2.98351142e-11, 1.10946664e-10, 2.84278782e-10, 6.82640871e-10,
#        1.50481935e-09, 2.99514637e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '3.15', '3.35'): (array([1.94752946e-04, 1.32540815e-04, 8.43891953e-05, 6.38435909e-05,
#        5.51546057e-05, 5.20567247e-05]), array([1.53194674e-07, 8.37075455e-07, 3.36866316e-06, 1.06923822e-05,
#        2.72835123e-05, 5.75354204e-05]), array([2.98351142e-11, 1.10946663e-10, 2.84278774e-10, 6.82640074e-10,
#        1.50481136e-09, 2.99510554e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '3.25', '3.45'): (array([1.94752946e-04, 1.32540815e-04, 8.43891949e-05, 6.38435889e-05,
#        5.51546021e-05, 5.20567200e-05]), array([1.53194674e-07, 8.37075406e-07, 3.36865900e-06, 1.06922981e-05,
#        2.72829295e-05, 5.75330926e-05]), array([2.98351142e-11, 1.10946657e-10, 2.84278421e-10, 6.82634687e-10,
#        1.50477912e-09, 2.99498409e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '3.35', '3.55'): (array([1.94752946e-04, 1.32540815e-04, 8.43891912e-05, 6.38435801e-05,
#        5.51545899e-05, 5.20567058e-05]), array([1.53194672e-07, 8.37074408e-07, 3.36862979e-06, 1.06920088e-05,
#        2.72815309e-05, 5.75287278e-05]), array([2.98351138e-11, 1.10946524e-10, 2.84275943e-10, 6.82616122e-10,
#        1.50470165e-09, 2.99475606e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '3.45', '3.65'): (array([1.94752946e-04, 1.32540809e-04, 8.43891747e-05, 6.38435539e-05,
#        5.51545599e-05, 5.20566741e-05]), array([1.53194619e-07, 8.37067986e-07, 3.36853186e-06, 1.06913813e-05,
#        2.72792061e-05, 5.75227465e-05]), array([2.98351033e-11, 1.10945668e-10, 2.84267623e-10, 6.82575778e-10,
#        1.50457261e-09, 2.99444287e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '3.55', '3.75'): (array([1.94752946e-04, 1.32540785e-04, 8.43891279e-05, 6.38434970e-05,
#        5.51545027e-05, 5.20566160e-05]), array([1.53194089e-07, 8.37046282e-07, 3.36832430e-06, 1.06904046e-05,
#        2.72762528e-05, 5.75162159e-05]), array([2.98350002e-11, 1.10942771e-10, 2.84249950e-10, 6.82512814e-10,
#        1.50440816e-09, 2.99409956e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '3.65', '3.85'): (array([1.94752945e-04, 1.32540718e-04, 8.43890301e-05, 6.38433969e-05,
#        5.51544089e-05, 5.20565223e-05]), array([1.53191717e-07, 8.36998880e-07, 3.36800668e-06, 1.06892189e-05,
#        2.72731972e-05, 5.75102515e-05]), array([2.98345381e-11, 1.10936433e-10, 2.84222817e-10, 6.82436047e-10,
#        1.50423707e-09, 2.99378369e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '3.75', '3.95'): (array([1.94752940e-04, 1.32540576e-04, 8.43888635e-05, 6.38432430e-05,
#        5.51542690e-05, 5.20563835e-05]), array([1.53185504e-07, 8.36924412e-07, 3.36762801e-06, 1.06880371e-05,
#        2.72705378e-05, 5.75056696e-05]), array([2.98333273e-11, 1.10926444e-10, 2.84190300e-10, 6.82358947e-10,
#        1.50408658e-09, 2.99353719e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '3.85', '4.05'): (array([1.94752922e-04, 1.32540333e-04, 8.43886160e-05, 6.38430274e-05,
#        5.51540787e-05, 5.20562010e-05]), array([1.53174204e-07, 8.36832499e-07, 3.36725447e-06, 1.06870397e-05,
#        2.72686060e-05, 5.75029305e-05]), array([2.98311237e-11, 1.10914058e-10, 2.84157944e-10, 6.82292968e-10,
#        1.50397484e-09, 2.99338411e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '3.95', '4.15'): (array([1.94752877e-04, 1.32539971e-04, 8.43882833e-05, 6.38427521e-05,
#        5.51538433e-05, 5.20559857e-05]), array([1.53158563e-07, 8.36737884e-07, 3.36693908e-06, 1.06863399e-05,
#        2.72675766e-05, 5.75022065e-05]), array([2.98280708e-11, 1.10901215e-10, 2.84130209e-10, 6.82245351e-10,
#        1.50391165e-09, 2.99333404e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '4.05', '4.25'): (array([1.94752790e-04, 1.32539487e-04, 8.43878715e-05, 6.38424263e-05,
#        5.51535746e-05, 5.20557489e-05]), array([1.53140990e-07, 8.36654884e-07, 3.36671942e-06, 1.06860045e-05,
#        2.72675110e-05, 5.75034302e-05]), array([2.98246350e-11, 1.10889809e-10, 2.84110286e-10, 6.82220452e-10,
#        1.50390070e-09, 2.99338412e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '4.15', '4.35'): (array([1.94752638e-04, 1.32538893e-04, 8.43873922e-05, 6.38420622e-05,
#        5.51532856e-05, 5.20554953e-05]), array([1.53124126e-07, 8.36593576e-07, 3.36661611e-06, 1.06860483e-05,
#        2.72683401e-05, 5.75062938e-05]), array([2.98213273e-11, 1.10881186e-10, 2.84099954e-10, 6.82219358e-10,
#        1.50393855e-09, 2.99351860e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '4.25', '4.45'): (array([1.94752407e-04, 1.32538201e-04, 8.43868611e-05, 6.38416730e-05,
#        5.51529827e-05, 5.20552195e-05]), array([1.53110234e-07, 8.36560079e-07, 3.36663278e-06, 1.06864333e-05,
#        2.72698854e-05, 5.75103378e-05]), array([2.98185865e-11, 1.10876168e-10, 2.84099573e-10, 6.82239778e-10,
#        1.50401552e-09, 2.99371326e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '4.35', '4.55'): (array([1.94752108e-04, 1.32537425e-04, 8.43862935e-05, 6.38412656e-05,
#        5.51526647e-05, 5.20549199e-05]), array([1.53100990e-07, 8.36556784e-07, 3.36675837e-06, 1.06870883e-05,
#        2.72719279e-05, 5.75150870e-05]), array([2.98167404e-11, 1.10875082e-10, 2.84108260e-10, 6.82277240e-10,
#        1.50411949e-09, 2.99394324e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '4.45', '4.65'): (array([1.94751757e-04, 1.32536583e-04, 8.43857003e-05, 6.38408462e-05,
#        5.51523264e-05, 5.20545946e-05]), array([1.53097175e-07, 8.36581292e-07, 3.36696835e-06, 1.06879220e-05,
#        2.72742445e-05, 5.75201141e-05]), array([2.98159437e-11, 1.10877626e-10, 2.84123982e-10, 6.82325983e-10,
#        1.50423804e-09, 2.99418622e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '4.55', '4.75'): (array([1.94751365e-04, 1.32535695e-04, 8.43850928e-05, 6.38404206e-05,
#        5.51519583e-05, 5.20542188e-05]), array([1.53098763e-07, 8.36628021e-07, 3.36723305e-06, 1.06888437e-05,
#        2.72766406e-05, 5.75250998e-05]), array([2.98161931e-11, 1.10883076e-10, 2.84144274e-10, 6.82380280e-10,
#        1.50436015e-09, 2.99442413e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '4.65', '4.85'): (array([1.94750933e-04, 1.32534791e-04, 8.43844872e-05, 6.38399865e-05,
#        5.51515632e-05, 5.20537622e-05]), array([1.53105098e-07, 8.36690079e-07, 3.36752455e-06, 1.06897811e-05,
#        2.72789698e-05, 5.75298517e-05]), array([2.98173607e-11, 1.10890545e-10, 2.84166832e-10, 6.82435483e-10,
#        1.50447783e-09, 2.99464522e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '4.75', '4.95'): (array([1.94750456e-04, 1.32533900e-04, 8.43838966e-05, 6.38395467e-05,
#        5.51511403e-05, 5.20532046e-05]), array([1.53115004e-07, 8.36760325e-07, 3.36781944e-06, 1.06906810e-05,
#        2.72811411e-05, 5.75342711e-05]), array([2.98192169e-11, 1.10899109e-10, 2.84189728e-10, 6.82488229e-10,
#        1.50458604e-09, 2.99484318e-09])), ('3.5', '1.0', '1.0', '1.01', '2212', 'jul', '4.85', '5.05'): (array([1.94749936e-04, 1.32533042e-04, 8.43833221e-05, 6.38390913e-05,
#        5.51506468e-05, 5.20525301e-05]), array([1.53127120e-07, 8.36832638e-07, 3.36810124e-06, 1.06915122e-05,
#        2.72831283e-05, 5.75383295e-05]), array([2.98214968e-11, 1.10907975e-10, 2.84211572e-10, 6.82536425e-10,
#        1.50468217e-09, 2.99501563e-09]))}

# %%
e0_values = [2.15,2.25,2.35,2.45,2.55,2.65,2.75,2.85,2.95,3.05,3.15,3.25,3.35,3.45,3.55,3.65,3.75,3.85,3.95,4.05,4.15,4.25,4.35,4.45,4.55,4.65,4.75,4.85,4.95] #energy bin where the modification is applied

log_e_bins = np.log10(mceq_instance.e_bins)  # Convert edges to log scale
bin_centers = 0.5 * (log_e_bins[:-1] + log_e_bins[1:])  # Midpoints of log bins
indices = np.searchsorted(bin_centers, e0_values)
cs_pr_selected = cs_proton[indices]

# %%
def get_data(fixed_params):
    e0_values_list = ['2.05', '2.15', '2.25', '2.35', '2.45', '2.55', '2.65', '2.75', '2.85', '2.95', 
                      '3.05', '3.15', '3.25', '3.35', '3.45', '3.55', '3.65', '3.75', '3.85', '3.95', 
                      '4.05', '4.15', '4.25', '4.35', '4.45', '4.55', '4.65', '4.75', '4.85','4.95','5.05']

    sel_data = []
    R_low = []
    R_high = []

    for e0 in range(len(e0_values_list) - 2):
        key = (fixed_params[0], "1.0", "1.0", fixed_params[1],"2212", "apr", e0_values_list[e0], e0_values_list[e0+2])
        R_mod, r_low, r_high = data[key]
        sel_data.append(R_mod)
        R_low.append(r_low)
        R_high.append(r_high)

    return np.array(sel_data), np.array(R_low), np.array(R_high)

# %%
data_15_csp101,R_low_15_csp101, R_high_15_csp101 = get_data(("1.5", "1.01"))
data_35_csp101,R_low_35_csp101, R_high_35_csp101 = get_data(("3.5", "1.01"))

R_def_15, R_def_low_15, R_def_high_15 = data[('1.5', '1.0', '1.0', '1.0', '2212', 'apr', '2.05', 'inf')]  
R_def_35, R_def_low_35, R_def_high_35 = data[('3.5', '1.0', '1.0', '1.0', '2212', 'apr', '2.05', 'inf')]  

R_def_15_jan, R_def_low_15_jan, R_def_high_15_jan = data[('1.5', '1.0', '1.0', '1.0', '2212', 'jan', '2.05', 'inf')]  
R_def_35_jan, R_def_low_35_jan, R_def_high_35_jan = data[('3.5', '1.0', '1.0', '1.0','2212', 'jan', '2.05', 'inf')]  

R_def_15_jul, R_def_low_15_jul, R_def_high_15_jul = data[('1.5', '1.0', '1.0', '1.0','2212', 'jul', '2.05', 'inf')]  
R_def_35_jul, R_def_low_35_jul, R_def_high_35_jul = data[('3.5', '1.0', '1.0', '1.0','2212', 'jul', '2.05', 'inf')]

# %% [markdown]
# same plots as fpr pion-air

# %%
def dRdSig(R_array,cs_pr):

    slope = np.ndarray(shape=((len(e0_values)-2),6)) 

    for i in range(len(e0_values)-2):
        R1 = R_array[i]
        R2 = R_array[i+1]
        
        slope[i] = (R2-R1)/(0.01*cs_pr[i])

    return slope

# %%
dRdsig_15_cs101 = dRdSig(data_15_csp101,cs_pr_selected) # need to know energy bin here
dRdsig_35_cs101 = dRdSig(data_35_csp101,cs_pr_selected)

dRdsig_low_15_cs101 = dRdSig(R_low_15_csp101,cs_pr_selected) # need to know energy bin here
dRdsig_low_35_cs101 = dRdSig(R_low_35_csp101,cs_pr_selected)

dRdsig_high_15_cs101 = dRdSig(R_high_15_csp101,cs_pr_selected) # need to know energy bin here
dRdsig_high_35_cs101 = dRdSig(R_high_35_csp101,cs_pr_selected)

# %%
# Get six evenly spaced colors from the 'inferno' colormap
cmap = plt.get_cmap("inferno")
colors = [cmap(i) for i in np.linspace(0, 0.85, 7)]  # Max at 0.85 to avoid bright yellow

# %%
for j in range(len(angles)):
    plt.plot(e0_values[1:-1], dRdsig_35_cs101[:,j], drawstyle='steps-post',label=str(np.round(angles[j],decimals=0)) + 'deg',color=colors[j])

# Add labels and title
plt.xlabel('log(threshold e0/GeV)')
plt.title('cs_pr = 1.01, $d$ = 3.5km')
plt.ylabel('dR/dsigma in mb$^{-1}$')
#plt.yscale('log')
plt.legend()
plt.tight_layout()
if norm:
    plt.savefig(plot_dir + 'dRdsgima_cspr1.01_depth3.5_renormed_current_e0_1bin_proton.png')
else:
    plt.savefig(plot_dir + 'dRdsgima_cspr1.01_depth3.5_renormed_current_e0_1bin_nonorm_proton.png')

# %%
for j in range(len(angles)):
    plt.plot(e0_values[1:-1], dRdsig_high_35_cs101[:,j], drawstyle='steps-post',label=str(np.round(angles[j],decimals=0)) + 'deg',color=colors[j])

# Add labels and title
plt.xlabel('log(threshold e0/GeV)')
plt.title('cs_pr = 1.01, $d$ = 3.5km')
plt.ylabel('dR high/dsigma in mb$^{-1}$')
#plt.yscale('log')
plt.legend()
plt.tight_layout()
if norm:
    plt.savefig(plot_dir + 'dRhighdsgima_cspr1.01_depth3.5_renormed_current_e0_1bin.png')
else:
    plt.savefig(plot_dir + 'dRhighdsgima_cspr1.01_depth3.5_renormed_current_e0_1bin_nonorm.png')

# %%
for j in range(len(angles)):
    plt.plot(e0_values[1:-1], dRdsig_low_35_cs101[:,j], drawstyle='steps-post',label=str(np.round(angles[j],decimals=0)) + 'deg',color=colors[j])

# Add labels and title
plt.xlabel('log(threshold e0/GeV)')
plt.title('cs_pr = 1.01, $d$ = 3.5km')
plt.ylabel('dR low/dsigma in mb$^{-1}$')
#plt.yscale('log')
plt.legend()
plt.tight_layout()
if norm:
    plt.savefig(plot_dir + 'dRlowdsgima_cspr1.01_depth3.5_renormed_current_e0_1bin.png')
else:
    plt.savefig(plot_dir + 'dRlowdsgima_cspr.01_depth3.5_renormed_current_e0_1bin_nonorm.png')

# %%
for j in range(len(angles)):
    plt.plot(e0_values[1:-1], dRdsig_15_cs101[:,j], drawstyle='steps-post',label=str(np.round(angles[j],decimals=0)) + 'deg',color=colors[j])

# Add labels and title
plt.xlabel('log(threshold e0/GeV)')
plt.title('cs_pr = 1.01, $d$ = 1.5km')
plt.ylabel('dR/dsigma in mb$^{-1}$')
#plt.yscale('log')
plt.legend()
plt.tight_layout()
#plt.ylim(-0.05,0.05)
if norm:
    plt.savefig(plot_dir + 'dRdsgima_cspr1.01_depth1.5_renormed_current_e0_1bin_proton.png')
else:
    plt.savefig(plot_dir + 'dRdsgima_cspr1.01_depth1.5_renormed_current_e0_1bin_nonorm_proton.png')

# %%
for j in range(len(angles)):
    plt.plot(e0_values[1:-1], dRdsig_low_15_cs101[:,j], drawstyle='steps-post',label=str(np.round(angles[j],decimals=0)) + 'deg',color=colors[j])

# Add labels and title
plt.xlabel('log(threshold e0/GeV)')
plt.title('cs_pr = 1.01, $d$ = 1.5km')
plt.ylabel('dR low/dsigma in mb$^{-1}$')
#plt.yscale('log')
plt.legend()
plt.tight_layout()
#plt.ylim(-0.05,0.05)
if norm:
    plt.savefig(plot_dir + 'dRlowdsgima_cspr1.01_depth1.5_renormed_current_e0_1bin.png')
else:
    plt.savefig(plot_dir + 'dRlowdsgima_cspr1.01_depth1.5_renormed_current_e0_1bin_nonorm.png')

# %%
for j in range(len(angles)):
    plt.plot(e0_values[1:-1], dRdsig_high_15_cs101[:,j], drawstyle='steps-post',label=str(np.round(angles[j],decimals=0)) + 'deg',color=colors[j])

# Add labels and title
plt.xlabel('log(threshold e0/GeV)')
plt.title('cs_pr = 1.01, $d$ = 1.5km')
plt.ylabel('dR high/dsigma in mb$^{-1}$')
#plt.yscale('log')
plt.legend()
plt.tight_layout()
#plt.ylim(-0.05,0.05)
if norm:
    plt.savefig(plot_dir + 'dRhighdsgima_cspr1.01_depth1.5_renormed_current_e0_1bin.png')
else:
    plt.savefig(plot_dir + 'dRhighdsgima_cspr1.01_depth1.5_renormed_current_e0_1bin_nonorm.png')

# %%
for j in range(len(angles)):
    plt.plot(e0_values[1:-1], np.abs(dRdsig_35_cs101[:,j]**(-1)), drawstyle='steps-post',label=str(np.round(angles[j],decimals=0)) + 'deg',color=colors[j])

# Add labels and title
plt.xlabel('log(threshold e0/GeV)')
plt.title('cs_pr = 1.01, $d$ = 3.5km')
plt.ylabel('|dsigma/dR| in mb')
plt.yscale('log')
plt.legend()
plt.tight_layout()
#plt.ylim(-0.03,0.03)
if norm:
    plt.savefig(plot_dir + 'dsgimadR_cspr1.01_depth3.5_renormed_current_e0_1bin_proton.png')
else:
    plt.savefig(plot_dir + 'dsgimadR_cspr.01_depth3.5_renormed_current_e0_1bin_nonorm_proton.png')
# Out:
# /tmp/ipykernel_1912285/2537242162.py:2: RuntimeWarning: divide by zero encountered in reciprocal
#   plt.plot(e0_values[1:-1], np.abs(dRdsig_35_cs101[:,j]**(-1)), drawstyle='steps-post',label=str(np.round(angles[j],decimals=0)) + 'deg',color=colors[j])

# %%
for j in range(len(angles)):
    plt.plot(e0_values[1:-1], np.abs(dRdsig_low_35_cs101[:,j]**(-1)), drawstyle='steps-post',label=str(np.round(angles[j],decimals=0)) + 'deg',color=colors[j])

# Add labels and title
plt.xlabel('log(threshold e0/GeV)')
plt.title('cs_pr = 1.01, $d$ = 3.5km')
plt.ylabel('|dsigma/dR low| in mb')
plt.yscale('log')
plt.legend()
plt.tight_layout()
#plt.ylim(-0.03,0.03)
if norm:
    plt.savefig(plot_dir + 'dsgimadRlow_cspr1.01_depth3.5_renormed_current_e0_1bin.png')
else:
    plt.savefig(plot_dir + 'dsgimadRlow_cspr1.01_depth3.5_renormed_current_e0_1bin_nonorm.png')
# Out:
# /tmp/ipykernel_1912285/474690301.py:2: RuntimeWarning: divide by zero encountered in reciprocal
#   plt.plot(e0_values[1:-1], np.abs(dRdsig_low_35_cs101[:,j]**(-1)), drawstyle='steps-post',label=str(np.round(angles[j],decimals=0)) + 'deg',color=colors[j])

# %%
for j in range(len(angles)):
    plt.plot(e0_values[1:-1], np.abs(dRdsig_high_35_cs101[:,j]**(-1)), drawstyle='steps-post',label=str(np.round(angles[j],decimals=0)) + 'deg',color=colors[j])

# Add labels and title
plt.xlabel('log(threshold e0/GeV)')
plt.title('cs_pr = 1.01, $d$ = 3.5km')
plt.ylabel('|dsigma/dR high| in mb')
plt.yscale('log')
plt.legend()
plt.tight_layout()
#plt.ylim(-0.03,0.03)
if norm:
    plt.savefig(plot_dir + 'dsgimadRhigh_cspr1.01_depth3.5_renormed_current_e0_1bin.png')
else:
    plt.savefig(plot_dir + 'dsgimadRhigh_cspr1.01_depth3.5_renormed_current_e0_1bin_nonorm.png')
# Out:
# /tmp/ipykernel_1912285/1092849212.py:2: RuntimeWarning: divide by zero encountered in reciprocal
#   plt.plot(e0_values[1:-1], np.abs(dRdsig_high_35_cs101[:,j]**(-1)), drawstyle='steps-post',label=str(np.round(angles[j],decimals=0)) + 'deg',color=colors[j])

# %% [markdown]
# how does R change with changing threshold

# %%
for j in range(len(angles)):
    plt.plot(e0_values[1:-1], data_35_csp101[1:-1,j], drawstyle='steps-post',label=str(np.round(angles[j],decimals=0)) + 'deg')
    plt.plot(e0_values[1:-1],R_def_35[j]*np.ones(len(e0_values[1:-1])),label='default')

    # Add labels and title
    plt.xlabel('log(threshold e0/GeV)')
    plt.title('cs_pr = 1.01, $d$ = 3.5km')
    plt.ylabel('R')
    #plt.yscale('log')
    plt.legend()
    plt.tight_layout()
    if norm:
        plt.savefig(plot_dir + 'E_R_cspr1.01_depth3.5_renormed_current_e0_1bin_'+ str(np.round(angles[j],decimals=0)) +'deg.png')
    else:
        plt.savefig(plot_dir + 'E_R_cspr1.01_depth3.5_renormed_current_e0_1bin_nonorm_'+ str(np.round(angles[j],decimals=0)) +'deg.png')
    plt.show()
    plt.clf()

# %%
for j in range(len(angles)):
    plt.plot(e0_values[1:-1], data_15_csp101[1:-1,j], drawstyle='steps-post',label=str(np.round(angles[j],decimals=0)) + 'deg')
    plt.plot(e0_values[1:-1],R_def_15[j]*np.ones(len(e0_values[1:-1])),label='default')

    # Add labels and title
    plt.xlabel('log(threshold e0/GeV)')
    plt.title('cs_pr = 1.01, $d$ = 1.5km')
    plt.ylabel('dR/dsigma in mb$^{-1}$')
    #plt.yscale('log')
    plt.legend()
    plt.tight_layout()
    if norm:
        plt.savefig(plot_dir + 'E_R_cspr1.01_depth1.5_renormed_current_e0_1bin_' + str(np.round(angles[j],decimals=0)) +'deg_proton.png')
    else:
        plt.savefig(plot_dir + 'E_R_cspr1.01_depth1.5_renormed_current_e0_1bin_nonorm' + str(np.round(angles[j],decimals=0)) +'deg_proton.png')
    plt.clf()

# %%
for j in range(len(angles)):
    plt.plot(e0_values[1:-1], R_low_35_csp101[1:-1,j], drawstyle='steps-post',label=str(np.round(angles[j],decimals=0)) + 'deg')
    plt.plot(e0_values[1:-1],R_def_low_35[j]*np.ones(len(e0_values[1:-1])),label='default')

    # Add labels and title
    plt.xlabel('log(threshold e0/GeV)')
    plt.title('cs_k = 1.01, $d$ = 3.5km')
    plt.ylabel('R low')
    #plt.yscale('log')
    plt.legend()
    plt.tight_layout()
    if norm:
        plt.savefig(plot_dir + 'E_Rlow_cspr1.01_depth3.5_renormed_current_e0_1bin_'+ str(np.round(angles[j],decimals=0)) +'deg.png')
    else:
        plt.savefig(plot_dir + 'E_Rlow_cspr1.01_depth3.5_renormed_current_e0_1bin_nonorm_'+ str(np.round(angles[j],decimals=0)) +'deg.png')
    plt.show()
    plt.clf()

# %%
for j in range(len(angles)):
    plt.plot(e0_values[1:-1], R_high_35_csp101[1:-1,j], drawstyle='steps-post',label=str(np.round(angles[j],decimals=0)) + 'deg')
    plt.plot(e0_values[1:-1],R_def_high_35[j]*np.ones(len(e0_values[1:-1])),label='default')

    # Add labels and title
    plt.xlabel('log(threshold e0/GeV)')
    plt.title('cs_pr = 1.01, $d$ = 3.5km')
    plt.ylabel('R high')
    #plt.yscale('log')
    plt.legend()
    plt.tight_layout()
    if norm:
        plt.savefig(plot_dir + 'E_Rhigh_cspr1.01_depth3.5_renormed_current_e0_1bin_'+ str(np.round(angles[j],decimals=0)) +'deg.png')
    else:
        plt.savefig(plot_dir + 'E_Rhigh_cspr1.01_depth3.5_renormed_current_e0_1bin_nonorm_'+ str(np.round(angles[j],decimals=0)) +'deg.png')
    plt.show()
    plt.clf()

# %%
for j in range(len(angles)):
    plt.plot(e0_values[1:-1], R_low_15_csp101[1:-1,j], drawstyle='steps-post',label=str(np.round(angles[j],decimals=0)) + 'deg')
    plt.plot(e0_values[1:-1],R_def_low_15[j]*np.ones(len(e0_values[1:-1])),label='default')

    # Add labels and title
    plt.xlabel('log(threshold e0/GeV)')
    plt.title('cs_pr = 1.01, $d$ = 1.5km')
    plt.ylabel('R low')
    #plt.yscale('log')
    plt.legend()
    plt.tight_layout()
    if norm:
        plt.savefig(plot_dir + 'E_Rlow_cspr1.01_depth1.5_renormed_current_e0_1bin_' + str(np.round(angles[j],decimals=0)) +'.png')
    else:
        plt.savefig(plot_dir + 'E_Rlow_cspr1.01_depth1.5_renormed_current_e0_1bin_nonorm' + str(np.round(angles[j],decimals=0)) +'.png')
    plt.clf()

for j in range(len(angles)):
    plt.plot(e0_values[1:-1], R_high_15_csp101[1:-1,j], drawstyle='steps-post',label=str(np.round(angles[j],decimals=0)) + 'deg')
    plt.plot(e0_values[1:-1],R_def_high_15[j]*np.ones(len(e0_values[1:-1])),label='default')

    # Add labels and title
    plt.xlabel('log(threshold e0/GeV)')
    plt.title('cs_pr = 1.01, $d$ = 1.5km')
    plt.ylabel('R high')
    #plt.yscale('log')
    plt.legend()
    plt.tight_layout()
    if norm:
        plt.savefig(plot_dir + 'E_Rhigh_cspr1.01_depth1.5_renormed_current_e0_1bin_' + str(np.round(angles[j],decimals=0)) +'.png')
    else:
        plt.savefig(plot_dir + 'E_Rhigh_cspr1.01_depth1.5_renormed_current_e0_1bin_nonorm' + str(np.round(angles[j],decimals=0)) +'.png')
    plt.clf()

# %%
slant_depths = helper.slant_depths[2:-1:4]

# %%
# Define bin edges and e0 values
bin_edges_cs = np.arange(2.1, 5.1 + 0.1, 0.1)
e0_values_list = [2.15, 2.25, 2.35, 2.45, 2.55, 2.65, 2.75, 2.85, 2.95, 3.05, 
                  3.15, 3.25, 3.35, 3.45, 3.55, 3.65, 3.75, 3.85, 3.95, 4.05, 
                  4.15, 4.25, 4.35, 4.45, 4.55, 4.65, 4.75, 4.85, 4.95, 5.05, 5.15]
X = 1.5
cs_p = 1.0
cs_k = 1.0

# Define subplot layout
n_plots = len(bin_edges_cs) - 3
ncols = 4
nrows = (n_plots + ncols - 1) // ncols  # Compute the number of rows needed

fig, axes = plt.subplots(nrows, ncols, figsize=(4 * ncols, 3 * nrows), sharex=True)

# Flatten axes array for easier iteration
axes = axes.flatten()

# Define a consistent color
plot_color = "blue"

# Loop through the bins and generate each subplot
for e in range(n_plots):
    ax = axes[e]
    
    # Compute the ratio
    ratio = (1e4 * helper.mult_dist(X, 0., pm.GlobalSplineFitBeta(), "yields_apr", 2212, 1.0,1.0, 1.01, e0_values_list[e], e0_values_list[e+1], norm=False) / 
             helper.rates(X, 0.0, "apr", 2212, 1.0, 1.0,1.01, e0_values_list[e], e0_values_list[e+1])) / \
            (1e4 * helper.mult_dist(X, 0., pm.GlobalSplineFitBeta(), "yields_apr", 2212, 1.0, 1.0,1.0, 2.05, norm=False) / 
             helper.rates(X, 0.0, "apr", 2212, 1.0, 1.0, 1.0,2.05, "None"))
    #print(ratio)
     
    # Compute a reasonable y-scale using powers of ten, focusing on deviations
    y_min = np.min(ratio)
    y_max = np.max(ratio)
    
    # Find the nearest powers of 10 for scaling
    ymin = 10 ** np.floor(np.log10(y_min))
    ymax = 10 ** np.ceil(np.log10(y_max))
    
    # Apply zoom-in logic to highlight deviations
    #ax.set_ylim([ymin * 0.8, ymax * 1.2])  # Slight expansion to avoid cutting edges
    
    # Plot the baseline line
    #ax.plot(helper.n_mu_vec, np.ones(len(helper.n_mu_vec)), color='black', linestyle="--")

    # Plot the ratio curve
    ax.plot(helper.n_mu_vec, ratio, label=f"{np.round(bin_edges_cs[e], 1)} ≤ log(E) ≤ {np.round(bin_edges_cs[e+1], 1)}", 
            color=plot_color)
    
    # Compute a reasonable y-scale using powers of ten
    #y_min = np.min(ratio)
    #y_max = np.max(ratio)
    
    # Find the nearest powers of 10
    #ymin = 10 ** np.floor(np.log10(y_min))
    #ymax = 10 ** np.ceil(np.log10(y_max))
    
    # Ensure y=1 is within the range
    #ymin = min(ymin, 1e-1)  # Prevent cutting off at unreasonable small values
    #ymax = max(ymax, 10)  # Prevent cutting off useful range
    
    #ax.set_ylim([ymin, ymax])

    # Set labels and title
    ax.set_title(f"{np.round(bin_edges_cs[e], 1)} ≤ log(E) ≤ {np.round(bin_edges_cs[e+1], 1)}", fontsize=10)
    ax.grid(True)

# Remove empty subplots if any
for i in range(n_plots, len(axes)):
    fig.delaxes(axes[i])

# Set common labels
fig.supxlabel("Muon multiplicity per bundle")
fig.supylabel(r"$dN_{mod}/dN_\mu / dN/dN_\mu$")
plt.tight_layout()
plt.savefig(plot_dir + 'bundlespectrum_ratio_cs_pr1.01_energybin_test_1.5km_proton.png')
plt.show()

# %%
X = 3.5
cs_k =1.0
n_plots = len(bin_edges_cs) - 3
ncols = 4
nrows = (n_plots + ncols - 1) // ncols  # Compute the number of rows needed

fig, axes = plt.subplots(nrows, ncols, figsize=(4 * ncols, 3 * nrows), sharex=True)

# Flatten axes array for easier iteration
axes = axes.flatten()

# Define a consistent color
plot_color = "blue"

# Loop through the bins and generate each subplot
for e in range(n_plots):
    ax = axes[e]
    
    # Compute the ratio
    ratio = (1e4 * helper.mult_dist(X, 0., pm.GlobalSplineFitBeta(), "yields_apr", 2212, 1.0, cs_k,1.01, e0_values_list[e], e0_values_list[e+1], norm=False) / 
             helper.rates(X, 0.0, "apr", 2212, 1.0, cs_k, 1.01, e0_values_list[e], e0_values_list[e+1])) / \
            (1e4 * helper.mult_dist(X, 0., pm.GlobalSplineFitBeta(), "yields_apr", 2212, 1.0, 1.0, 1.0, 2.05, "None",norm=False) / 
             helper.rates(X, 0.0, "apr", 2212, 1.0, 1.0, 1.0, 2.05, 'None'))
    
     
    # Compute a reasonable y-scale using powers of ten, focusing on deviations
    y_min = np.min(ratio)
    y_max = np.max(ratio)
    
    # Find the nearest powers of 10 for scaling
    ymin = 10 ** np.floor(np.log10(y_min))
    ymax = 10 ** np.ceil(np.log10(y_max))
    
    # Apply zoom-in logic to highlight deviations
    #ax.set_ylim([ymin * 0.8, ymax * 1.2])  # Slight expansion to avoid cutting edges
    
    # Plot the baseline line
    #ax.plot(helper.n_mu_vec, np.ones(len(helper.n_mu_vec)), color='black', linestyle="--")

    # Plot the ratio curve
    ax.plot(helper.n_mu_vec, ratio, label=f"{np.round(bin_edges_cs[e], 1)} ≤ log(E) ≤ {np.round(bin_edges_cs[e+1], 1)}", 
            color=plot_color)
    
    # Compute a reasonable y-scale using powers of ten
    #y_min = np.min(ratio)
    #y_max = np.max(ratio)
    
    # Find the nearest powers of 10
    #ymin = 10 ** np.floor(np.log10(y_min))
    #ymax = 10 ** np.ceil(np.log10(y_max))
    
    # Ensure y=1 is within the range
    #ymin = min(ymin, 1e-1)  # Prevent cutting off at unreasonable small values
    #ymax = max(ymax, 10)  # Prevent cutting off useful range
    
    #ax.set_ylim([ymin, ymax])

    # Set labels and title
    ax.set_title(f"{np.round(bin_edges_cs[e], 1)} ≤ log(E) ≤ {np.round(bin_edges_cs[e+1], 1)}", fontsize=10)
    ax.grid(True)

# Remove empty subplots if any
for i in range(n_plots, len(axes)):
    fig.delaxes(axes[i])

# Set common labels
fig.supxlabel("Muon multiplicity per bundle")
fig.supylabel(r"$dN_{mod}/dN_\mu / dN/dN_\mu$")
plt.tight_layout()
plt.savefig(plot_dir + 'bundlespectrum_ratio_cs_pr1.01_energybin_test_3.5km_proton.png')
plt.show()

# %%
cs_p = 1.0
cs_k = 1.0
cs_pr = 1.01



plt.figure(figsize=(5.0, 3.5))
lines=[]
angle = 0.0
for i, X in enumerate(slant_depths[0:2]):  
    plt.semilogy(
        mh.n_mu_vec,
        1e4*mh.mult_dist(X,
                        0.,
                        pm.GlobalSplineFitBeta(),"yields_apr",
                        2212,
                        cs_p, cs_k, cs_pr,2.25,2.45,
                        norm=False#))[0]
                    ) / mh.rates(X, angle, "apr", 2212, cs_p, cs_k, cs_pr, 2.25,2.45),
        c=colors[i],
        label=r"{0:3.1f} km.w.e.".format(X),
    )[0]

for i, X in enumerate(slant_depths[0:2]):  
    plt.semilogy(
        mh.n_mu_vec,
        1e4*mh.mult_dist(X,
                        0.,
                        pm.GlobalSplineFitBeta(),"yields_apr",
                        2212,
                        1.0, 1.0, 1.0, 2.05,
                        norm=False#))[0]
                    ) / mh.rates(X, angle, "apr", 2212, 1.0, 1.0, 1.0, 2.05,"inf"),
        c=colors[i], ls='--',
        label=r"{0:3.1f} km.w.e.".format(X),
    )[0]
    
plt.xlabel("Muon multiplicity per bundle")
plt.ylabel(r"dN/dN$_\mu$ (s cm$^2$ sr)$^{-1}$")
lines.append(mlines.Line2D([], [], color='k', linestyle="--", label="aprl"))
plt.legend(handles=lines, frameon=False, loc="lower left")
plt.legend(frameon=False, ncol=2)
# plt.ylim(1e-11, 8e-5)
# plt.xlim(4,100)

plt.grid()
plt.tight_layout()

plt.savefig(plot_dir + 'multiperbundle_energybintest_cs_pr1.01_depth1.5km.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 13
#       9 angle = 0.0
#      10 for i, X in enumerate(slant_depths[0:2]):
#      11     plt.semilogy(
#      12         mh.n_mu_vec,
# ---> 13         1e4*mh.mult_dist(X,
#      14                         0.,
#      15                         pm.GlobalSplineFitBeta(),"yields_apr",
#      16                         2212,
#      17                         cs_p, cs_k, cs_pr,2.25,2.45,
#      18                         norm=False#))[0]
#      19                     ) / mh.rates(X, angle, "apr", 2212, cs_p, cs_k, cs_pr, 2.25,2.45),
#      20         c=colors[i],
#      21         label=r"{0:3.1f} km.w.e.".format(X),
#      22     )[0]
#      24 for i, X in enumerate(slant_depths[0:2]):
#      25     plt.semilogy(
#      26         mh.n_mu_vec,
#      27         1e4*mh.mult_dist(X,
#    (...)
#      35         label=r"{0:3.1f} km.w.e.".format(X),
#      36     )[0]
#
# TypeError: mult_dist() got multiple values for argument 'norm'

# %%
from matplotlib.colors import LogNorm
z = np.abs(dRdsig_15_cs101)
z_min = 1.e-15
z_max = 1.e-6
print(z_min,z_max)

# Calculate the first and last bin edges
angle_edges = np.zeros(len(angles) + 1)
angle_edges[0] = angles[0] - (angles[1] - angles[0]) / 2
angle_edges[-1] = angles[-1] + (angles[-1] - angles[-2]) / 2

# Calculate edges for the interior bins
for i in range(1, len(angles)):
    angle_edges[i] = (angles[i-1] + angles[i]) / 2

plt.figure(figsize=(8, 6))
plt.pcolormesh(e0_values[:-1],  np.cos(np.deg2rad(angle_edges)), z.T, cmap='plasma_r', 
               norm=LogNorm(vmin=z_min, vmax=z_max), shading='auto')

# Add color bar with logarithmic scale and set the min/max values
cbar = plt.colorbar(label="abs(dR/dsig)", norm=LogNorm(vmin=z_min, vmax=z_max))

# Set labels
plt.xlabel('Energy pion / GeV ')
plt.ylabel('cos($\Theta$)')


# Display the plot
plt.savefig(plot_dir + '2D_dRdsig_angle_energy_ebintest_d1.5km_proton.png')
plt.show()
# Out:
# <>:25: SyntaxWarning: invalid escape sequence '\T'
# <>:25: SyntaxWarning: invalid escape sequence '\T'
# /tmp/ipykernel_1912285/3416303321.py:25: SyntaxWarning: invalid escape sequence '\T'
#   plt.ylabel('cos($\Theta$)')
# 1e-15 1e-06

# %%
z = np.abs(dRdsig_35_cs101)
plt.figure(figsize=(8, 6))
plt.pcolormesh(e0_values[:-1],  np.cos(np.deg2rad(angle_edges)), z.T, cmap='plasma_r', 
               norm=LogNorm(vmin=z_min, vmax=z_max), shading='auto')

# Add color bar with logarithmic scale and set the min/max values
cbar = plt.colorbar(label="dR/dsig", norm=LogNorm(vmin=z_min, vmax=z_max))

# Set labels
plt.xlabel('Energy pion / GeV ')
plt.ylabel('cos($\Theta$)')


# Display the plot
plt.savefig(plot_dir + '2D_dRdsig_angle_energy_ebintest_d3.5km_proton.png')
plt.show()
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\T'
# <>:11: SyntaxWarning: invalid escape sequence '\T'
# /tmp/ipykernel_1912285/1849796575.py:11: SyntaxWarning: invalid escape sequence '\T'
#   plt.ylabel('cos($\Theta$)')

# %%
z = np.abs(dRdsig_15_cs101**(-1))
z_max = 1e20
z_min = 1.e6
print(z_min, z_max)


# Calculate the first and last bin edges
angle_edges = np.zeros(len(angles) + 1)
angle_edges[0] = angles[0] - (angles[1] - angles[0]) / 2
angle_edges[-1] = angles[-1] + (angles[-1] - angles[-2]) / 2

# Calculate edges for the interior bins
for i in range(1, len(angles)):
    angle_edges[i] = (angles[i-1] + angles[i]) / 2

plt.figure(figsize=(8, 6))
plt.pcolormesh(e0_values[:-1],  np.cos(np.deg2rad(angle_edges)), z.T, cmap='plasma_r', 
               norm=LogNorm(vmin=z_min, vmax=z_max), shading='auto')

# Add color bar with logarithmic scale and set the min/max values
cbar = plt.colorbar(label="abs(dsig/dR)", norm=LogNorm(vmin=z_min, vmax=z_max))

# Set labels
plt.xlabel('Energy pion / GeV ')
plt.ylabel('cos($\Theta$)')


# Display the plot
plt.savefig(plot_dir + '2D_dsigdR_angle_energy_ebintest_d1.5km_proton.png')
plt.show()
# Out:
# 1000000.0 1e+20
# <>:25: SyntaxWarning: invalid escape sequence '\T'
# <>:25: SyntaxWarning: invalid escape sequence '\T'
# /tmp/ipykernel_1912285/340933147.py:25: SyntaxWarning: invalid escape sequence '\T'
#   plt.ylabel('cos($\Theta$)')
# /tmp/ipykernel_1912285/340933147.py:1: RuntimeWarning: divide by zero encountered in reciprocal
#   z = np.abs(dRdsig_15_cs101**(-1))

# %%
z = np.abs(dRdsig_35_cs101**(-1))


plt.figure(figsize=(8, 6))
plt.pcolormesh(e0_values[:-1],  np.cos(np.deg2rad(angle_edges)), z.T, cmap='plasma_r', 
               norm=LogNorm(vmin=z_min, vmax=z_max), shading='auto')

# Add color bar with logarithmic scale and set the min/max values
cbar = plt.colorbar(label="abs(dsig/dR)", norm=LogNorm(vmin=z_min, vmax=z_max))

# Set labels
plt.xlabel('Energy pion / GeV ')
plt.ylabel('cos($\Theta$)')


# Display the plot
plt.savefig(plot_dir + '2D_dsigdR_angle_energy_ebintest_d3.5km_proton.png')
plt.show()
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\T'
# <>:13: SyntaxWarning: invalid escape sequence '\T'
# /tmp/ipykernel_1912285/969304083.py:13: SyntaxWarning: invalid escape sequence '\T'
#   plt.ylabel('cos($\Theta$)')
# /tmp/ipykernel_1912285/969304083.py:1: RuntimeWarning: divide by zero encountered in reciprocal
#   z = np.abs(dRdsig_35_cs101**(-1))
