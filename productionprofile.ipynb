# %%
from plot_productionprofile import *

# %%
conf_folders = config_handler.get_json_config('configfile.local.json')

# %%
interactionmodel1 = 'SIBYLL2.3c'
interactionmodel2 = 'EPOSLHC'
cs_k1 = '1.0'
cs_k2 = '1.0'
cs_p1 = '1.0'
cs_p2 = '1.0'
season1= 'January'
season2= 'January'

# %%
plot_profiles(conf_folders,interactionmodel1,cs_k1,cs_p1,season1,interactionmodel2,cs_k2,cs_p2,season2)
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a
# MCEqRun::set_density_model(): Setting density profile to MSIS00_IC ('SouthPole', 'July')
# MSIS00IceCubeCentered::set_theta(): latitude = -90.00 for zenith angle =  0.00
# MSIS00IceCubeCentered::set_theta(): latitude = -80.00 for zenith angle = 95.00
# MSIS00IceCubeCentered::set_theta(): theta = 95.00 below horizon. using theta = 85.00
# MCEqRun::set_density_model(): Setting density profile to MSIS00_IC ('SouthPole', 'July')
# MSIS00IceCubeCentered::set_theta(): latitude = -90.00 for zenith angle =  0.00
# MSIS00IceCubeCentered::set_theta(): latitude = -80.00 for zenith angle = 95.00
# MSIS00IceCubeCentered::set_theta(): theta = 95.00 below horizon. using theta = 85.00

# %%
interactionmodel1 = 'SIBYLL2.3c'
interactionmodel2 = 'DPMJET-III-19.1'
cs_k1 = '1.0'
cs_k2 = '1.0'
cs_p1 = '1.0'
cs_p2 = '1.0'
season1= 'January'
season2= 'January'
plot_profiles(conf_folders,interactionmodel1,cs_k1,cs_p1,season1,interactionmodel2,cs_k2,cs_p2,season2)
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a
# MCEqRun::set_density_model(): Setting density profile to MSIS00_IC ('SouthPole', 'July')
# MSIS00IceCubeCentered::set_theta(): latitude = -90.00 for zenith angle =  0.00
# MSIS00IceCubeCentered::set_theta(): latitude = -80.00 for zenith angle = 95.00
# MSIS00IceCubeCentered::set_theta(): theta = 95.00 below horizon. using theta = 85.00
# MCEqRun::set_density_model(): Setting density profile to MSIS00_IC ('SouthPole', 'July')
# MSIS00IceCubeCentered::set_theta(): latitude = -90.00 for zenith angle =  0.00
# MSIS00IceCubeCentered::set_theta(): latitude = -80.00 for zenith angle = 95.00
# MSIS00IceCubeCentered::set_theta(): theta = 95.00 below horizon. using theta = 85.00

# %%
interactionmodel1 = 'SIBYLL2.3c'
interactionmodel2 = 'DPMJET-III-19.1'
cs_k1 = '1.0'
cs_k2 = '1.0'
cs_p1 = '1.0'
cs_p2 = '1.0'
season1= 'July'
season2= 'July'
plot_profiles(conf_folders,interactionmodel1,cs_k1,cs_p1,season1,interactionmodel2,cs_k2,cs_p2,season2)
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a
# MCEqRun::set_density_model(): Setting density profile to MSIS00_IC ('SouthPole', 'July')
# MSIS00IceCubeCentered::set_theta(): latitude = -90.00 for zenith angle =  0.00
# MSIS00IceCubeCentered::set_theta(): latitude = -80.00 for zenith angle = 95.00
# MSIS00IceCubeCentered::set_theta(): theta = 95.00 below horizon. using theta = 85.00
# MCEqRun::set_density_model(): Setting density profile to MSIS00_IC ('SouthPole', 'July')
# MSIS00IceCubeCentered::set_theta(): latitude = -90.00 for zenith angle =  0.00
# MSIS00IceCubeCentered::set_theta(): latitude = -80.00 for zenith angle = 95.00
# MSIS00IceCubeCentered::set_theta(): theta = 95.00 below horizon. using theta = 85.00

# %%
interactionmodel1 = 'SIBYLL2.3c'
interactionmodel2 = 'EPOSLHC'
cs_k1 = '1.0'
cs_k2 = '1.0'
cs_p1 = '1.0'
cs_p2 = '1.0'
season1= 'July'
season2= 'July'
plot_profiles(conf_folders,interactionmodel1,cs_k1,cs_p1,season1,interactionmodel2,cs_k2,cs_p2,season2)
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a
# MCEqRun::set_density_model(): Setting density profile to MSIS00_IC ('SouthPole', 'July')
# MSIS00IceCubeCentered::set_theta(): latitude = -90.00 for zenith angle =  0.00
# MSIS00IceCubeCentered::set_theta(): latitude = -80.00 for zenith angle = 95.00
# MSIS00IceCubeCentered::set_theta(): theta = 95.00 below horizon. using theta = 85.00
# MCEqRun::set_density_model(): Setting density profile to MSIS00_IC ('SouthPole', 'July')
# MSIS00IceCubeCentered::set_theta(): latitude = -90.00 for zenith angle =  0.00
# MSIS00IceCubeCentered::set_theta(): latitude = -80.00 for zenith angle = 95.00
# MSIS00IceCubeCentered::set_theta(): theta = 95.00 below horizon. using theta = 85.00

# %%
interactionmodel1 = 'SIBYLL2.3c'
interactionmodel2 = 'SIBYLL2.3c'
cs_k1 = '1.0'
cs_k2 = '0.5'
cs_p1 = '1.0'
cs_p2 = '0.5'
season1= 'July'
season2= 'July'
plot_profiles(conf_folders,interactionmodel1,cs_k1,cs_p1,season1,interactionmodel2,cs_k2,cs_p2,season2)
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a
# MCEqRun::set_density_model(): Setting density profile to MSIS00_IC ('SouthPole', 'July')
# MSIS00IceCubeCentered::set_theta(): latitude = -90.00 for zenith angle =  0.00
# MSIS00IceCubeCentered::set_theta(): latitude = -80.00 for zenith angle = 95.00
# MSIS00IceCubeCentered::set_theta(): theta = 95.00 below horizon. using theta = 85.00
# MCEqRun::set_density_model(): Setting density profile to MSIS00_IC ('SouthPole', 'July')
# MSIS00IceCubeCentered::set_theta(): latitude = -90.00 for zenith angle =  0.00
# MSIS00IceCubeCentered::set_theta(): latitude = -80.00 for zenith angle = 95.00
# MSIS00IceCubeCentered::set_theta(): theta = 95.00 below horizon. using theta = 85.00

# %%
interactionmodel1 = 'SIBYLL2.3c'
interactionmodel2 = 'SIBYLL2.3c'
cs_k1 = '1.0'
cs_k2 = '0.5'
cs_p1 = '1.0'
cs_p2 = '0.5'
season1= 'January'
season2= 'January'
plot_profiles(conf_folders,interactionmodel1,cs_k1,cs_p1,season1,interactionmodel2,cs_k2,cs_p2,season2)
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a
# MCEqRun::set_density_model(): Setting density profile to MSIS00_IC ('SouthPole', 'July')
# MSIS00IceCubeCentered::set_theta(): latitude = -90.00 for zenith angle =  0.00
# MSIS00IceCubeCentered::set_theta(): latitude = -80.00 for zenith angle = 95.00
# MSIS00IceCubeCentered::set_theta(): theta = 95.00 below horizon. using theta = 85.00
# MCEqRun::set_density_model(): Setting density profile to MSIS00_IC ('SouthPole', 'July')
# MSIS00IceCubeCentered::set_theta(): latitude = -90.00 for zenith angle =  0.00
# MSIS00IceCubeCentered::set_theta(): latitude = -80.00 for zenith angle = 95.00
# MSIS00IceCubeCentered::set_theta(): theta = 95.00 below horizon. using theta = 85.00

# %%
interactionmodel1 = 'SIBYLL2.3c'
interactionmodel2 = 'SIBYLL2.3c'
cs_k1 = '0.5'
cs_k2 = '1.0'
cs_p1 = '1.5'
cs_p2 = '1.0'
season1= 'January'
season2= 'January'
plot_profiles(conf_folders,interactionmodel1,cs_k1,cs_p1,season1,interactionmodel2,cs_k2,cs_p2,season2)
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a
# MCEqRun::set_density_model(): Setting density profile to MSIS00_IC ('SouthPole', 'July')
# MSIS00IceCubeCentered::set_theta(): latitude = -90.00 for zenith angle =  0.00
# MSIS00IceCubeCentered::set_theta(): latitude = -80.00 for zenith angle = 95.00
# MSIS00IceCubeCentered::set_theta(): theta = 95.00 below horizon. using theta = 85.00
# MCEqRun::set_density_model(): Setting density profile to MSIS00_IC ('SouthPole', 'July')
# MSIS00IceCubeCentered::set_theta(): latitude = -90.00 for zenith angle =  0.00
# MSIS00IceCubeCentered::set_theta(): latitude = -80.00 for zenith angle = 95.00
# MSIS00IceCubeCentered::set_theta(): theta = 95.00 below horizon. using theta = 85.00

# %%
interactionmodel1 = 'SIBYLL2.3c'
interactionmodel2 = 'SIBYLL2.3c'
cs_k1 = '1.5'
cs_k2 = '1.0'
cs_p1 = '0.5'
cs_p2 = '1.0'
season1= 'January'
season2= 'January'
plot_profiles(conf_folders,interactionmodel1,cs_k1,cs_p1,season1,interactionmodel2,cs_k2,cs_p2,season2)
# Out:
# MCEqRun::set_interaction_model(): SIBYLL23C
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): HillasGaisser2012 H3a
# MCEqRun::set_density_model(): Setting density profile to MSIS00_IC ('SouthPole', 'July')
# MSIS00IceCubeCentered::set_theta(): latitude = -90.00 for zenith angle =  0.00
# MSIS00IceCubeCentered::set_theta(): latitude = -80.00 for zenith angle = 95.00
# MSIS00IceCubeCentered::set_theta(): theta = 95.00 below horizon. using theta = 85.00
# MCEqRun::set_density_model(): Setting density profile to MSIS00_IC ('SouthPole', 'July')
# MSIS00IceCubeCentered::set_theta(): latitude = -90.00 for zenith angle =  0.00
# MSIS00IceCubeCentered::set_theta(): latitude = -80.00 for zenith angle = 95.00
# MSIS00IceCubeCentered::set_theta(): theta = 95.00 below horizon. using theta = 85.00
